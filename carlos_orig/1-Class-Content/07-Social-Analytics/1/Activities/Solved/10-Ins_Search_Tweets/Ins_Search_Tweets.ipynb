# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? hungry hippos
# {'search_metadata': {'completed_in': 0.05,
#   'count': 15,
#   'max_id': 930514188241338369,
#   'max_id_str': '930514188241338369',
#   'next_results': '?max_id=930474003055210496&q=hungry%20hippos&include_entities=1',
#   'query': 'hungry+hippos',
#   'refresh_url': '?since_id=930514188241338369&q=hungry%20hippos&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 19:14:05 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 242222569,
#       'id_str': '242222569',
#       'indices': [40, 52],
#       'name': 'Lucas Sullivan',
#       'screen_name': 'Ljrepresent'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 930514188241338369,
#    'id_str': '930514188241338369',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RLRT: "Is Hungry Hungry Hippos vore?" - @Ljrepresent',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jul 18 18:35:47 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Not actually a cartoon dog in a suit. Opinions are my own.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gamesradar.com',
#         'expanded_url': 'http://www.gamesradar.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/SjsY2RfLpx'}]}},
#     'favourites_count': 3180,
#     'follow_request_sent': False,
#     'followers_count': 3618,
#     'following': False,
#     'friends_count': 483,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 168213663,
#     'id_str': '168213663',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 132,
#     'location': '',
#     'name': 'Sam Prell',
#     'notifications': False,
#     'profile_background_color': 'EBEBEB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/168213663/1509986264',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/793924072677793793/zTs2tYMj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/793924072677793793/zTs2tYMj_normal.jpg',
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'DFDFDF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SamPrell',
#     'statuses_count': 16746,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/SjsY2RfLpx',
#     'utc_offset': -21600,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 18:52:24 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 467646084,
#       'id_str': '467646084',
#       'indices': [3, 16],
#       'name': 'Mandy Land',
#       'screen_name': 'MandyLand314'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930508732643069953,
#    'id_str': '930508732643069953',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 17,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 16:10:27 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 36,
#     'favorited': False,
#     'geo': None,
#     'id': 930467975974588418,
#     'id_str': '930467975974588418',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 18 18:00:06 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Funny with a side of cleavage.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Sep 22 23:22:52 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '90% funny ½ the time | Chicago sports junkie | beer connoisseur | metalhead | closet WWE fan | anti-Nazi | pro-grammar Nazi | https://t.co/LpC4z71JWq',
#     'entities': {'description': {'urls': [{'display_url': 'favstar.fm/users/Rockstea…',
#         'expanded_url': 'http://favstar.fm/users/RocksteadyRicky',
#         'indices': [126, 149],
#         'url': 'https://t.co/LpC4z71JWq'}]},
#      'url': {'urls': [{'display_url': 'twitter.com/search?q=-filt…',
#         'expanded_url': 'https://twitter.com/search?q=-filter%3Areplies%20from%3ARocksteadyRicky',
#         'indices': [0, 23],
#         'url': 'https://t.co/Id27iEsxR7'}]}},
#     'favourites_count': 12426,
#     'follow_request_sent': False,
#     'followers_count': 1884,
#     'following': False,
#     'friends_count': 1937,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 193906765,
#     'id_str': '193906765',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 14,
#     'location': "Illinois. Don't say the ''S''.",
#     'name': 'Ricky Rocksteady',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/193906765/1463535505',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/797473330882379777/iVAsxycn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797473330882379777/iVAsxycn_normal.jpg',
#     'profile_link_color': '002F6C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RocksteadyRicky',
#     'statuses_count': 5883,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/Id27iEsxR7',
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 18:30:50 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930503305889009664,
#    'id_str': '930503305889009664',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'All these money hungry hungry hippos wanna love me',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun May 14 04:28:04 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'my daughter is my heart and soul 💗 Shanell Berdine-Grace ~',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4392,
#     'follow_request_sent': False,
#     'followers_count': 140,
#     'following': False,
#     'friends_count': 590,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 863611846200315904,
#     'id_str': '863611846200315904',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'WhereTheTreesMeetTheFreeway',
#     'name': '🌀✨',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863611846200315904/1494736526',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/909479993226530817/9ojII72c_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909479993226530817/9ojII72c_normal.jpg',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'eyebrowze__',
#     'statuses_count': 4785,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 18:19:32 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 467646084,
#       'id_str': '467646084',
#       'indices': [3, 16],
#       'name': 'Mandy Land',
#       'screen_name': 'MandyLand314'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930500463195230208,
#    'id_str': '930500463195230208',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 17,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 16:10:27 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 36,
#     'favorited': False,
#     'geo': None,
#     'id': 930467975974588418,
#     'id_str': '930467975974588418',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 18 18:00:06 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Funny with a side of cleavage.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jan 06 14:37:49 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'https://t.co/Kom1IDBznB',
#     'entities': {'description': {'urls': [{'display_url': 'favstar.fm/users/gingerfa…',
#         'expanded_url': 'http://favstar.fm/users/gingerfaced',
#         'indices': [0, 23],
#         'url': 'https://t.co/Kom1IDBznB'}]},
#      'url': {'urls': [{'display_url': 'mobile.twitter.com/search?q=From%…',
#         'expanded_url': 'https://mobile.twitter.com/search?q=From%3Agingerfaced%20exclude%3Areplies&src=typed_query',
#         'indices': [0, 23],
#         'url': 'https://t.co/8znEkZ6Xmf'}]}},
#     'favourites_count': 65130,
#     'follow_request_sent': False,
#     'followers_count': 19523,
#     'following': False,
#     'friends_count': 3406,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 234769937,
#     'id_str': '234769937',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 658,
#     'location': 'Fort Worth, TX',
#     'name': 'Taylor',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/234769937/1482234202',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/930126937061814272/4QTEaJtI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/930126937061814272/4QTEaJtI_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'gingerfaced',
#     'statuses_count': 18209,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/8znEkZ6Xmf',
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 18:05:11 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/3yjLaWouYR',
#       'expanded_url': 'https://twitter.com/TeacherAMurray/status/930496851580616704/photo/1',
#       'id': 930496792940240898,
#       'id_str': '930496792940240898',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DOnJ5zfX4AIMCr3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DOnJ5zfX4AIMCr3.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/3yjLaWouYR'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 770000035044024322,
#       'id_str': '770000035044024322',
#       'indices': [75, 87],
#       'name': 'Michelle Matthews',
#       'screen_name': 'MMatthews68'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/3yjLaWouYR',
#       'expanded_url': 'https://twitter.com/TeacherAMurray/status/930496851580616704/photo/1',
#       'id': 930496792940240898,
#       'id_str': '930496792940240898',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DOnJ5zfX4AIMCr3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DOnJ5zfX4AIMCr3.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/3yjLaWouYR'},
#      {'display_url': 'pic.twitter.com/3yjLaWouYR',
#       'expanded_url': 'https://twitter.com/TeacherAMurray/status/930496851580616704/photo/1',
#       'id': 930496812661858304,
#       'id_str': '930496812661858304',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DOnJ689X4AAE6Ew.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DOnJ689X4AAE6Ew.jpg',
#       'sizes': {'large': {'h': 1535, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 899, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/3yjLaWouYR'},
#      {'display_url': 'pic.twitter.com/3yjLaWouYR',
#       'expanded_url': 'https://twitter.com/TeacherAMurray/status/930496851580616704/photo/1',
#       'id': 930496836078620672,
#       'id_str': '930496836078620672',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DOnJ8UMXUAAeziG.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DOnJ8UMXUAAeziG.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1536},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#        'small': {'h': 680, 'resize': 'fit', 'w': 510},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/3yjLaWouYR'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 930496851580616704,
#    'id_str': '930496851580616704',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Hungry hungry hippos for Phys. Ed today after practicing our HairUp dance! @MMatthews68 https://t.co/3yjLaWouYR',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Sep 22 00:17:57 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': 'Professional: mom, wife, teacher, multi-tasker, busy body',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 632,
#     'follow_request_sent': False,
#     'followers_count': 58,
#     'following': False,
#     'friends_count': 88,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 778750142656630784,
#     'id_str': '778750142656630784',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': 'Ontario, Canada',
#     'name': 'MrsMurraysClass',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TeacherAMurray',
#     'statuses_count': 315,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 17:52:08 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 467646084,
#       'id_str': '467646084',
#       'indices': [3, 16],
#       'name': 'Mandy Land',
#       'screen_name': 'MandyLand314'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930493566920556547,
#    'id_str': '930493566920556547',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 17,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 16:10:27 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 36,
#     'favorited': False,
#     'geo': None,
#     'id': 930467975974588418,
#     'id_str': '930467975974588418',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 18 18:00:06 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Funny with a side of cleavage.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu May 12 19:49:08 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Ghostwriter for your least favorite rappers, or your favorite rappers depending on how shitty your taste in music is.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'twitter.com/search?q=From%…',
#         'expanded_url': 'https://twitter.com/search?q=From%3A%40sincir3000&s=09',
#         'indices': [0, 23],
#         'url': 'https://t.co/SUB5PouBuH'}]}},
#     'favourites_count': 102143,
#     'follow_request_sent': False,
#     'followers_count': 6905,
#     'following': False,
#     'friends_count': 5459,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 297602233,
#     'id_str': '297602233',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 131,
#     'location': '',
#     'name': 'Jetpack Jimmy',
#     'notifications': False,
#     'profile_background_color': '4A913C',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/297602233/1507219966',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/922467923142369280/JNs4fFTR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922467923142369280/JNs4fFTR_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sincir3000',
#     'statuses_count': 51617,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/SUB5PouBuH',
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 17:49:26 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 467646084,
#       'id_str': '467646084',
#       'indices': [3, 16],
#       'name': 'Mandy Land',
#       'screen_name': 'MandyLand314'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930492886738722816,
#    'id_str': '930492886738722816',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 17,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 16:10:27 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 36,
#     'favorited': False,
#     'geo': None,
#     'id': 930467975974588418,
#     'id_str': '930467975974588418',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 18 18:00:06 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Funny with a side of cleavage.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 14 19:17:16 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Unqualified and uninterested. Or was that uninteresting? I can't remember. https://t.co/uBPl1YHOhj",
#     'entities': {'description': {'urls': [{'display_url': 'twitter.com/search?q=from%…',
#         'expanded_url': 'https://twitter.com/search?q=from%3Asouthwesternson%20exclude%3Areplies&src=typd',
#         'indices': [75, 98],
#         'url': 'https://t.co/uBPl1YHOhj'}]}},
#     'favourites_count': 12250,
#     'follow_request_sent': False,
#     'followers_count': 1327,
#     'following': False,
#     'friends_count': 1907,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2444377981,
#     'id_str': '2444377981',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 15,
#     'location': 'TX',
#     'name': 'Thanks, Seth!',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2444377981/1487454629',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/917516378592153600/kOCguXwA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917516378592153600/kOCguXwA_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'southwesternson',
#     'statuses_count': 7633,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 17:33:52 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/lgY2FAY2VI',
#       'expanded_url': 'https://twitter.com/smspillar/status/930484897441107971/video/1',
#       'id': 930484590283755520,
#       'id_str': '930484590283755520',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 930484897441107971,
#       'source_status_id_str': '930484897441107971',
#       'source_user_id': 758424284956127236,
#       'source_user_id_str': '758424284956127236',
#       'type': 'photo',
#       'url': 'https://t.co/lgY2FAY2VI'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 758424284956127236,
#       'id_str': '758424284956127236',
#       'indices': [3, 13],
#       'name': 'April Pillar',
#       'screen_name': 'smspillar'},
#      {'id': 740968153707122693,
#       'id_str': '740968153707122693',
#       'indices': [68, 78],
#       'name': 'Strongsville MS',
#       'screen_name': 'smsstangs'},
#      {'id': 2866153839,
#       'id_str': '2866153839',
#       'indices': [79, 87],
#       'name': 'BWHPESS',
#       'screen_name': 'BWHPESS'},
#      {'id': 330753647,
#       'id_str': '330753647',
#       'indices': [88, 103],
#       'name': 'Maddie Ziccardi',
#       'screen_name': 'ZaddieMiccardi'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#        'source_user': {'contributors_enabled': False,
#         'created_at': 'Wed Jul 27 22:10:15 +0000 2016',
#         'default_profile': False,
#         'default_profile_image': False,
#         'description': 'Life is what we make it, always has been, always will be.',
#         'entities': {'description': {'urls': []},
#          'url': {'urls': [{'display_url': 'sites.google.com/a/scsmustangs.…',
#             'expanded_url': 'https://sites.google.com/a/scsmustangs.org/mrs-pillar-s-class/',
#             'indices': [0, 23],
#             'url': 'https://t.co/eMcIj6ZNi2'}]}},
#         'favourites_count': 18,
#         'follow_request_sent': False,
#         'followers_count': 83,
#         'following': False,
#         'friends_count': 36,
#         'geo_enabled': False,
#         'has_extended_profile': False,
#         'id': 758424284956127236,
#         'id_str': '758424284956127236',
#         'is_translation_enabled': False,
#         'is_translator': False,
#         'lang': 'en',
#         'listed_count': 0,
#         'location': 'Strongsville, OH',
#         'name': 'April Pillar',
#         'notifications': False,
#         'profile_background_color': '000000',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_tile': False,
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/758424284956127236/1469677551',
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/758509037768105984/MDXo1Doo_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758509037768105984/MDXo1Doo_normal.jpg',
#         'profile_link_color': '19CF86',
#         'profile_sidebar_border_color': '000000',
#         'profile_sidebar_fill_color': '000000',
#         'profile_text_color': '000000',
#         'profile_use_background_image': False,
#         'protected': False,
#         'screen_name': 'smspillar',
#         'statuses_count': 74,
#         'time_zone': None,
#         'translator_type': 'none',
#         'url': 'https://t.co/eMcIj6ZNi2',
#         'utc_offset': None,
#         'verified': False}},
#       'display_url': 'pic.twitter.com/lgY2FAY2VI',
#       'expanded_url': 'https://twitter.com/smspillar/status/930484897441107971/video/1',
#       'id': 930484590283755520,
#       'id_str': '930484590283755520',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 930484897441107971,
#       'source_status_id_str': '930484897441107971',
#       'source_user_id': 758424284956127236,
#       'source_user_id_str': '758424284956127236',
#       'type': 'video',
#       'url': 'https://t.co/lgY2FAY2VI',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 45000,
#        'variants': [{'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/320x180/_qPc3YAvBpcxqFs6.mp4'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/640x360/SVJZkU1tOZvROnfX.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/pl/ux73vWcAmVGynMdS.m3u8'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/1280x720/OrYvE6GSEqznsZdS.mp4'}]}}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930488969988640768,
#    'id_str': '930488969988640768',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 17:17:41 +0000 2017',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/lgY2FAY2VI',
#        'expanded_url': 'https://twitter.com/smspillar/status/930484897441107971/video/1',
#        'id': 930484590283755520,
#        'id_str': '930484590283755520',
#        'indices': [89, 112],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#        'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#         'small': {'h': 191, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/lgY2FAY2VI'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 740968153707122693,
#        'id_str': '740968153707122693',
#        'indices': [53, 63],
#        'name': 'Strongsville MS',
#        'screen_name': 'smsstangs'},
#       {'id': 2866153839,
#        'id_str': '2866153839',
#        'indices': [64, 72],
#        'name': 'BWHPESS',
#        'screen_name': 'BWHPESS'},
#       {'id': 330753647,
#        'id_str': '330753647',
#        'indices': [73, 88],
#        'name': 'Maddie Ziccardi',
#        'screen_name': 'ZaddieMiccardi'}]},
#     'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#        'display_url': 'pic.twitter.com/lgY2FAY2VI',
#        'expanded_url': 'https://twitter.com/smspillar/status/930484897441107971/video/1',
#        'id': 930484590283755520,
#        'id_str': '930484590283755520',
#        'indices': [89, 112],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/930484590283755520/pu/img/bDCMR7FbZRCA6uGr.jpg',
#        'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#         'small': {'h': 191, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'video',
#        'url': 'https://t.co/lgY2FAY2VI',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 45000,
#         'variants': [{'bitrate': 320000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/320x180/_qPc3YAvBpcxqFs6.mp4'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/640x360/SVJZkU1tOZvROnfX.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/pl/ux73vWcAmVGynMdS.m3u8'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/930484590283755520/pu/vid/1280x720/OrYvE6GSEqznsZdS.mp4'}]}}]},
#     'favorite_count': 2,
#     'favorited': False,
#     'geo': None,
#     'id': 930484897441107971,
#     'id_str': '930484897441107971',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Hungry Hippos Fun during PE with my student teacher! @smsstangs @bwhpess @ZaddieMiccardi https://t.co/lgY2FAY2VI',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jul 27 22:10:15 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Life is what we make it, always has been, always will be.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'sites.google.com/a/scsmustangs.…',
#          'expanded_url': 'https://sites.google.com/a/scsmustangs.org/mrs-pillar-s-class/',
#          'indices': [0, 23],
#          'url': 'https://t.co/eMcIj6ZNi2'}]}},
#      'favourites_count': 18,
#      'follow_request_sent': False,
#      'followers_count': 83,
#      'following': False,
#      'friends_count': 36,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 758424284956127236,
#      'id_str': '758424284956127236',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 0,
#      'location': 'Strongsville, OH',
#      'name': 'April Pillar',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/758424284956127236/1469677551',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/758509037768105984/MDXo1Doo_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758509037768105984/MDXo1Doo_normal.jpg',
# ...
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 06 03:10:56 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "https://t.co/moRqCmuDUz Let's not talk about it.",
#     'entities': {'description': {'urls': [{'display_url': 'twitter.com/search?q=from%…',
#         'expanded_url': 'https://twitter.com/search?q=from%3ADaNaLa13&src=typd',
#         'indices': [0, 23],
#         'url': 'https://t.co/moRqCmuDUz'}]},
#      'url': {'urls': [{'display_url': 'favstar.fm/users/DanaLa13…',
#         'expanded_url': 'http://favstar.fm/users/DanaLa13/recent',
#         'indices': [0, 23],
#         'url': 'https://t.co/IQWMi3xiZ1'}]}},
#     'favourites_count': 109866,
#     'follow_request_sent': False,
#     'followers_count': 52764,
#     'following': False,
#     'friends_count': 36224,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 627990562,
#     'id_str': '627990562',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 722,
#     'location': 'In my own world ',
#     'name': 'ChaoticPerfection',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/627990562/1508179141',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/925841131585318912/JZHz95Y0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/925841131585318912/JZHz95Y0_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DaNaLa13',
#     'statuses_count': 81734,
#     'time_zone': 'Hawaii',
#     'translator_type': 'none',
#     'url': 'https://t.co/IQWMi3xiZ1',
#     'utc_offset': -36000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 16:37:07 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/930474686500229120',
#       'indices': [117, 140],
#       'url': 'https://t.co/cINBMln3SO'}],
#     'user_mentions': [{'id': 1733957150,
#       'id_str': '1733957150',
#       'indices': [0, 12],
#       'name': 'Laura',
#       'screen_name': 'LauraisLate'}]},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 930474686500229120,
#    'id_str': '930474686500229120',
#    'in_reply_to_screen_name': 'LauraisLate',
#    'in_reply_to_status_id': 930473875485478912,
#    'in_reply_to_status_id_str': '930473875485478912',
#    'in_reply_to_user_id': 1733957150,
#    'in_reply_to_user_id_str': '1733957150',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '@LauraisLate a Barnie the friendly dinosaur plushie, a game of hungry hungry hippos, an extra large pepperoni pizza… https://t.co/cINBMln3SO',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Sep 17 08:19:40 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Heya, just a silly guy who likes talking about silly things, but sometimes... also serious things... that i find silly o3o',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4498,
#     'follow_request_sent': False,
#     'followers_count': 440,
#     'following': False,
#     'friends_count': 438,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 74964792,
#     'id_str': '74964792',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 5,
#     'location': 'San Antonio, TX',
#     'name': 'muddles',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74964792/1363730955',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/915972599578021888/1s-nuWsn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915972599578021888/1s-nuWsn_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'muddyness',
#     'statuses_count': 21990,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 16:36:46 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930474599900418049,
#    'id_str': '930474599900418049',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'My life at the min is just one big game of hungry hippos',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jun 14 09:09:35 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Northern Monkey 🐒 - insta: georgiamariec2',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1638,
#     'follow_request_sent': False,
#     'followers_count': 324,
#     'following': False,
#     'friends_count': 404,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 155500855,
#     'id_str': '155500855',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Congleton, England',
#     'name': 'Georgia Cardall',
#     'notifications': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/155500855/1497651359',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/929399069428146177/edEFu0s4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/929399069428146177/edEFu0s4_normal.jpg',
#     'profile_link_color': '038543',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'GeorgiaMarieC2',
#     'statuses_count': 4337,
#     'time_zone': 'Amsterdam',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Nov 14 16:34:24 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 467646084,
#       'id_str': '467646084',
#       'indices': [3, 16],
#       'name': 'Mandy Land',
#       'screen_name': 'MandyLand314'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 930474003055210497,
#    'id_str': '930474003055210497',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 17,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Nov 14 16:10:27 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 36,
#     'favorited': False,
#     'geo': None,
#     'id': 930467975974588418,
#     'id_str': '930467975974588418',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 18 18:00:06 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Funny with a side of cleavage.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'twitr.buzz/mandyland314/f…',
#          'expanded_url': 'http://twitr.buzz/mandyland314/fav',
#          'indices': [0, 23],
#          'url': 'https://t.co/GFHGZnvu4x'}]}},
#      'favourites_count': 55365,
#      'follow_request_sent': False,
#      'followers_count': 3348,
#      'following': False,
#      'friends_count': 2665,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 467646084,
#      'id_str': '467646084',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 66,
#      'location': 'STL',
#      'name': 'Mandy Land',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/873189204/d96f2e5521bd6b333c323df876ee1505.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467646084/1403134203',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000334404131/9a6b888c794984f05de0a747687d5369_normal.jpeg',
#      'profile_link_color': '78293D',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MandyLand314',
#      'statuses_count': 19318,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/GFHGZnvu4x',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Apr 05 21:00:02 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Stuff, and beer, and tittays, and Jeeps, and the Denver Broncos.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'mobile.twitter.com/search?q=Fatty…',
#         'expanded_url': 'https://mobile.twitter.com/search?q=Fattydaddy7%20&src=typed_query',
#         'indices': [0, 23],
#         'url': 'https://t.co/DPstrJ0bZz'}]}},
#     'favourites_count': 75883,
#     'follow_request_sent': False,
#     'followers_count': 2811,
#     'following': False,
#     'friends_count': 2552,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3138446165,
#     'id_str': '3138446165',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 51,
#     'location': 'Michigan',
#     'name': 'Captain Creepy Pants',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3138446165/1510323140',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/928740828897562624/RD6mt0Uz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928740828897562624/RD6mt0Uz_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'fattydaddy7',
#     'statuses_count': 69358,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/DPstrJ0bZz',
#     'utc_offset': -18000,
#     'verified': False}}]}

# %%
# View Search Object
# print(public_tweets)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# RLRT: "Is Hungry Hungry Hippos vore?" - @Ljrepresent
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
# All these money hungry hungry hippos wanna love me
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
# Hungry hungry hippos for Phys. Ed today after practicing our HairUp dance! @MMatthews68 https://t.co/3yjLaWouYR
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
# RT @smspillar: Hungry Hippos Fun during PE with my student teacher! @smsstangs @bwhpess @ZaddieMiccardi https://t.co/lgY2FAY2VI
# Hungry Hippos Fun during PE with my student teacher! @smsstangs @bwhpess @ZaddieMiccardi https://t.co/lgY2FAY2VI
# Playing Hungry Hungry Hippos as a review for history today. Competitive working and fun learning make for a fun day… https://t.co/eH66YkkqUu
# RT @Shannon_Center: Intramural Human Hungry Hungry Hippos tonight (Tuesday) at 7pm!  Don't miss out on this fun event!!  #sxuintramurals #i…
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
# @LauraisLate a Barnie the friendly dinosaur plushie, a game of hungry hungry hippos, an extra large pepperoni pizza… https://t.co/cINBMln3SO
# My life at the min is just one big game of hungry hippos
# RT @MandyLand314: Hungry Hungry Hippos, but it's just my CW's talking about what to get for lunch.
