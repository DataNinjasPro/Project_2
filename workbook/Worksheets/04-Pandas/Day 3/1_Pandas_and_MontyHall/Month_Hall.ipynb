# %%
import random
import json 

from monty_print import print_values

# %%
results_list = []
iterations = 100

# %%
for guess in range(iterations):
    #set up the game that we are playing
    doors = ["a","b","c"]
    
    contestant_choice = random.choice(doors) # randomly select the choice of the contestant
    
    prize_door = random.choice(doors) # the prize door selected by the host
    
    trial =[contestant_choice] # want to store in a list the selected door of the contestant 
    
    # host decide to remove one door
    to_remove = contestant_choice #initially set it to the contestant for variable definition
    
    
#     Troubleshooting - IGNORE ------------------------------
#     while(to_remove == contestant_choice or to_remove == prize_door):
#         to_remove = random.choice(doors)
    
#     doors.remove(to_remove)
#     doors.remove(contestant_choice)
#     contestant_choice = doors[0]

#     trial.append(contestant_choice)
#     if contestant_choice == prize_door:
#         trial.append(1) # True
#     else:
#         trial.append(0) #FAlse

#     results_list.append(trial)
     
#      Troubleshooting - IGNORE ------------------------------
    
    while(to_remove == contestant_choice or to_remove == prize_door):
        to_remove = random.choice(doors) # if the contestant select the door with the prize at the start of the selection and you need to randomly remove 
        #the one of the other doors.
        
    #contestant switches to the other door
    doors.remove(to_remove) # remove it again from the list the door by the host

    doors.remove(contestant_choice)

    contestant_choice = doors[0] # no more option but to select the last door

    # append results of trials

    trial.append(contestant_choice)

    #Did the contestant select the right door win/loss?

    if contestant_choice == prize_door:
        trial.append(1) # True
    else:
        trial.append(0) #FAlse

    results_list.append(trial)

# %%
print_values(results_list)
# Out:
#     Distribution of Prior Selections p(A)
#
# Prior
# a    195
# b    200
# c    206
# Name: Result, dtype: int64
#
#     Distribution of Posterior Selections p(A|B)
#     Note, this is NOT the distribution of WINNING,
#     only the rate at which each value is selected
#
# Prior  Posterior
# a      a            57
#        b            61
#        c            77
# b      a            69
#        b            78
#        c            53
# c      a            58
#        b            83
#        c            65
# Name: Result, dtype: int64
#
#     Data on wins
#
#
#         Wins:336
#         Losses: 265
#         Winrate: 0.5590682196339434
#
#
#     Wins by Prior Selection
#
#        Trials  Wins   Winrate
# Prior
# a         195   111  0.569231
# b         200   112  0.560000
# c         206   113  0.548544
#
#     Wins by Posterior Selection
#
#                  Trials  Wins   Winrate
# Prior Posterior
# a     a              57    17  0.298246
# ...
