# %% [markdown]
# ### Import Libraries and Dependencies

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Read in File and Clean Data

# %%
# Read CSV
csv_path = Path('../Resources/crypto_data.csv')
crypto_data = pd.read_csv(csv_path, index_col='data_date', parse_dates=True, infer_datetime_format=True)
crypto_data
# Out:
#            cryptocurrency  data_priceUsd     data_time     timestamp
# data_date
# 2017-05-09        bitcoin            NaN  1.494288e+12  1.557285e+12
# 2017-05-10        bitcoin    1743.723523  1.494374e+12           NaN
# 2017-05-11        bitcoin    1828.678209  1.494461e+12           NaN
# 2017-05-12        bitcoin    1776.443919  1.494547e+12           NaN
# 2017-05-13        bitcoin    1714.964198  1.494634e+12           NaN
# ...                   ...            ...           ...           ...
# 2019-05-03       litecoin      76.435295  1.556842e+12           NaN
# 2019-05-04       litecoin      77.011308  1.556928e+12           NaN
# 2019-05-05       litecoin      75.974875  1.557014e+12           NaN
# 2019-05-06       litecoin      73.722948  1.557101e+12           NaN
# 2019-05-07       litecoin      75.566057  1.557187e+12           NaN
#
# [3556 rows x 4 columns]

# %%
# Drop all columns cryptocurrency and data_priceUsd
crypto_data = crypto_data.drop(columns=['data_time','timestamp'])
crypto_data
# Out:
#            cryptocurrency  data_priceUsd
# data_date
# 2017-05-09        bitcoin            NaN
# 2017-05-10        bitcoin    1743.723523
# 2017-05-11        bitcoin    1828.678209
# 2017-05-12        bitcoin    1776.443919
# 2017-05-13        bitcoin    1714.964198
# ...                   ...            ...
# 2019-05-03       litecoin      76.435295
# 2019-05-04       litecoin      77.011308
# 2019-05-05       litecoin      75.974875
# 2019-05-06       litecoin      73.722948
# 2019-05-07       litecoin      75.566057
#
# [3556 rows x 2 columns]

# %%
# Sort the dates in ascending order
crypto_data = crypto_data.sort_index()
crypto_data
# Out:
#            cryptocurrency  data_priceUsd
# data_date
# 2017-05-09        bitcoin            NaN
# 2017-05-09       litecoin      28.020288
# 2017-05-09         ripple       0.166990
# 2017-05-09       ethereum      84.915618
# 2017-05-10       litecoin      33.487730
# ...                   ...            ...
# 2019-05-07         ripple       0.299862
# 2019-05-07        bitcoin    5869.538627
# 2019-05-07       ethereum     174.858535
# 2019-05-07   bitcoin-cash     289.406309
# 2019-05-07       litecoin      75.566057
#
# [3556 rows x 2 columns]

# %%
# Are there any null values?
crypto_data.isnull().values.any()
# Where are the values missing values?
crypto_data.isnull()
# # Find out how many in each column 
crypto_data.isnull().sum() # add another sum() to chain to the total missing values
# Out:
# cryptocurrency     3
# data_priceUsd     14
# dtype: int64

# %%
# Check index of NA values
crypto_data = crypto_data.dropna()
crypto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3539 entries, 2017-05-09 to 2019-05-07
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cryptocurrency  3539 non-null   object
#  1   data_priceUsd   3539 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 82.9+ KB

# %%
crypto_data.isnull().sum()
crypto_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Group DataFrame and perform `count` aggregation

# %%
# Group by crypto data by cryptocurrency and perform count
crypto_data_grp = crypto_data.groupby('cryptocurrency').count() # add .count() to perform count
crypto_data_grp
# Out:
#                 data_priceUsd
# cryptocurrency
# bitcoin                   722
# bitcoin-cash              639
# ethereum                  722
# litecoin                  728
# ripple                    728

# %% [markdown]
# ### Group DataFrame without aggregate function

# %%
# Group by crypto data by cryptocurrency
crypto_data_grp = crypto_data.groupby('cryptocurrency')
crypto_data_grp.first() # add first() if you want to see the frist row of each group
# Out:
#                 data_priceUsd
# cryptocurrency
# bitcoin           1743.723523
# bitcoin-cash       344.090146
# ethereum            84.915618
# litecoin            28.020288
# ripple               0.166990

# %% [markdown]
# ### Group DataFrame by `cryptocurrency` and calculate the average `data_priceUsd`

# %%
# Calculate average data_priceUsd for each crypto
crypto_data_mean = crypto_data.groupby('cryptocurrency').mean()
crypto_data_mean
# Out:
#                 data_priceUsd
# cryptocurrency
# bitcoin          19339.922660
# bitcoin-cash      3476.844119
# ethereum          1346.037491
# litecoin           352.713468
# ripple               2.999459

# %% [markdown]
# ### Group by more than one column and calculate count

# %%
# Group by more than one column
multi_group = crypto_data.groupby(['cryptocurrency','data_priceUsd'])['data_priceUsd'].count()
multi_group
# Out:
# cryptocurrency  data_priceUsd
# bitcoin         1714.964198      1
#                 1742.722945      1
#                 1743.723523      1
#                 1776.443919      1
#                 1789.278913      1
#                                 ..
# ripple          2.507770         1
#                 2.665656         1
#                 2.667044         1
#                 2.709364         1
#                 2.999459         1
# Name: data_priceUsd, Length: 3539, dtype: int64

# %%
multi_group = crypto_data.groupby(['cryptocurrency','data_priceUsd']).data_priceUsd.count()
multi_group
# Out:
# cryptocurrency  data_priceUsd
# bitcoin         1714.964198      1
#                 1742.722945      1
#                 1743.723523      1
#                 1776.443919      1
#                 1789.278913      1
#                                 ..
# ripple          2.507770         1
#                 2.665656         1
#                 2.667044         1
#                 2.709364         1
#                 2.999459         1
# Name: data_priceUsd, Length: 3539, dtype: int64

# %% [markdown]
# ### Group by more than one column, round price to two decimal places, and calculate count

# %%
# Group by more than one column after rounding to two decimal places
rounded_crypto_data = crypto_data.round({'data_priceUsd': 4})
rounded_crypto_data
# Out:
#            cryptocurrency  data_priceUsd
# data_date
# 2017-05-09       litecoin        28.0203
# 2017-05-09         ripple         0.1670
# 2017-05-09       ethereum        84.9156
# 2017-05-10       litecoin        33.4877
# 2017-05-10        bitcoin      1743.7235
# ...                   ...            ...
# 2019-05-07         ripple         0.2999
# 2019-05-07        bitcoin      5869.5386
# 2019-05-07       ethereum       174.8585
# 2019-05-07   bitcoin-cash       289.4063
# 2019-05-07       litecoin        75.5661
#
# [3539 rows x 2 columns]

# %%
multi_group = rounded_crypto_data.groupby(['cryptocurrency','data_priceUsd'])['data_priceUsd'].count()
multi_group.head(50)
# Out:
# cryptocurrency  data_priceUsd
# bitcoin         1714.9642        1
#                 1742.7229        1
#                 1743.7235        1
#                 1776.4439        1
#                 1789.2789        1
#                 1802.0351        1
#                 1828.6782        1
#                 1840.5017        1
#                 1932.2850        1
#                 1958.2490        1
#                 1988.9614        1
#                 2041.0432        1
#                 2046.8920        1
#                 2071.9572        1
#                 2096.0676        1
#                 2132.6159        1
#                 2155.2271        1
#                 2192.0010        1
#                 2212.0498        1
#                 2250.8593        1
#                 2288.2415        1
#                 2291.0771        1
#                 2327.1945        1
#                 2346.6942        1
#                 2354.4149        1
#                 2357.0754        1
#                 2372.2884        1
#                 2372.6741        1
#                 2378.7925        1
#                 2407.7554        1
#                 2417.8674        1
#                 2451.2132        1
#                 2453.3487        1
#                 2457.4543        1
#                 2459.3475        1
#                 2466.3221        1
#                 2498.8424        1
#                 2500.4310        1
#                 2505.2799        1
#                 2520.6249        1
#                 2531.3779        1
#                 2539.8604        1
#                 2541.0371        1
#                 2543.7378        1
#                 2545.2185        1
#                 2545.8947        1
#                 2553.6769        1
#                 2566.4387        1
#                 2566.8513        1
#                 2569.0037        1
# Name: data_priceUsd, dtype: int64

# %% [markdown]
# ### Compare single column grouping to multicolumn grouping

# %%
# Compare one column group with multiple column group
single_group = crypto_data.groupby('cryptocurrency')['data_priceUsd'].count()
single_group
# Out:
# cryptocurrency
# bitcoin         1743.723523
# bitcoin-cash     344.090146
# ethereum          84.915618
# litecoin          28.020288
# ripple             0.166990
# Name: data_priceUsd, dtype: float64

# %% [markdown]
# ### Plot grouped data to generate more than one line on the same chart

# %%
# Plot data_priceUsd for each crypto across time
grouped_cryptos = crypto_data.groupby('cryptocurrency')['data_priceUsd'].plot(legend=True, figsize=(20,10)) #add , figsize=(20,10) to see graph bigger
grouped_cryptos
# Out:
# cryptocurrency
# bitcoin         AxesSubplot(0.125,0.2;0.775x0.68)
# bitcoin-cash    AxesSubplot(0.125,0.2;0.775x0.68)
# ethereum        AxesSubplot(0.125,0.2;0.775x0.68)
# litecoin        AxesSubplot(0.125,0.2;0.775x0.68)
# ripple          AxesSubplot(0.125,0.2;0.775x0.68)
# Name: data_priceUsd, dtype: object

# %%
# Bonus, print all multi items or single items group by 
single_group = crypto_data.groupby('cryptocurrency')['data_priceUsd']  
for key, item in single_group:
    print(single_group.get_group(key), "\n\n") # using the get_group() function
# Out:
# data_date
# 2017-05-10    1743.723523
# 2017-05-11    1828.678209
# 2017-05-12    1776.443919
# 2017-05-13    1714.964198
# 2017-05-14    1789.278913
#                  ...
# 2019-05-03    5635.648502
# 2019-05-04    5708.293373
# 2019-05-05    5738.591093
# 2019-05-06    5672.046269
# 2019-05-07    5869.538627
# Name: data_priceUsd, Length: 722, dtype: float64
#
#
# data_date
# 2017-08-01    344.090146
# 2017-08-02    647.992009
# 2017-08-03    506.293007
# 2017-08-04    309.921863
# 2017-08-05    230.983515
#                  ...
# 2019-05-03    281.440627
# 2019-05-04    286.525161
# 2019-05-05    290.394285
# 2019-05-06    285.086507
# 2019-05-07    289.406309
# Name: data_priceUsd, Length: 639, dtype: float64
#
#
# data_date
# 2017-05-09     84.915618
# 2017-05-10     88.177676
# 2017-05-11     88.432233
# 2017-05-12     88.646770
# 2017-05-13     86.503299
#                  ...
# 2019-05-03    164.020596
# 2019-05-04    163.025682
# 2019-05-05    161.789768
# 2019-05-06    165.506767
# 2019-05-07    174.858535
# Name: data_priceUsd, Length: 722, dtype: float64
#
#
# data_date
# 2017-05-09    28.020288
# 2017-05-10    33.487730
# 2017-05-11    30.966247
# 2017-05-12    29.658289
# 2017-05-13    27.381262
#                 ...
# 2019-05-03    76.435295
# 2019-05-04    77.011308
# 2019-05-05    75.974875
# 2019-05-06    73.722948
# 2019-05-07    75.566057
# Name: data_priceUsd, Length: 728, dtype: float64
#
#
# data_date
# 2017-05-09    0.166990
# 2017-05-10    0.179671
# 2017-05-11    0.178919
# 2017-05-12    0.195019
# 2017-05-13    0.210569
#                 ...
# 2019-05-03    0.301492
# 2019-05-04    0.301342
# 2019-05-05    0.298673
# 2019-05-06    0.297357
# 2019-05-07    0.299862
# Name: data_priceUsd, Length: 728, dtype: float64

# %%
multi_group = rounded_crypto_data.groupby(['cryptocurrency','data_priceUsd'])['data_priceUsd']
for key, item in multi_group:
    print(multi_group.get_group(key), "\n\n") # using the get_group() function
# Out:
# data_date
# 2017-05-13    1714.9642
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-15    1742.7229
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-10    1743.7235
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-12    1776.4439
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-14    1789.2789
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-17    1802.0351
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-11    1828.6782
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-18    1840.5017
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-19    1932.285
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-16    1958.249
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-20    1988.9614
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-21    2041.0432
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-27    2046.892
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-17    2071.9572
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-15    2096.0676
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-22    2132.6159
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-28    2155.2271
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-23    2192.001
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-29    2212.0498
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-30    2250.8593
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-18    2288.2415
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-14    2291.0771
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-19    2327.1945
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-11    2346.6942
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-12    2354.4149
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-15    2357.0754
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-01    2372.2884
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-26    2372.6741
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-13    2378.7925
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-02    2407.7554
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-27    2417.8674
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-01    2451.2132
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-10    2453.3487
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-16    2457.4543
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-02    2459.3475
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-26    2466.3221
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-20    2498.8424
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-03    2500.431
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-04    2505.2799
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-08    2520.6249
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-26    2531.3779
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-30    2539.8604
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-03    2541.0371
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-28    2543.7378
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-09    2545.2185
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-05-25    2545.8947
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-07    2553.6769
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-17    2566.4387
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-29    2566.8513
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-25    2569.0037
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-18    2570.4721
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-19    2570.7849
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-05    2588.9515
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-05    2590.6413
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-27    2597.7125
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-06    2606.4737
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-04    2612.2555
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-25    2639.382
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-14    2644.4253
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-24    2671.631
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-20    2675.4288
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-22    2689.3516
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-13    2697.9214
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-30    2707.2755
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-21    2714.1539
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-21    2725.3905
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-02    2727.949
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-23    2734.3678
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-29    2743.7321
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-08    2746.1159
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-03    2757.4284
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-24    2758.0041
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-28    2759.9125
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-23    2774.0822
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-12    2782.4335
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-31    2787.8712
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-07-22    2789.302
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-01    2793.5617
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-07    2807.9937
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-09    2817.291
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-06    2819.7413
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-04    2842.1135
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-10    2846.7352
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-06-11    2894.7766
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-05    3161.3145
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-06    3234.1647
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-15    3239.2274
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-16    3281.677
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-14    3282.419
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-07    3312.5353
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-09    3353.1546
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-17    3399.8989
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-07    3401.0456
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-06    3401.5059
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-07    3401.8835
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-10    3403.6714
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-13    3413.2751
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-15    3414.1288
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-08    3423.8151
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-29    3426.6454
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-08    3427.0901
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-11    3435.5312
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-12    3453.5157
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-01    3455.2242
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-04    3457.9624
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-30    3458.6496
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-05    3459.1958
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-31    3462.7295
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-28    3476.0724
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-03    3476.106
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-02    3477.037
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-08    3489.1396
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-11    3518.3843
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-09    3534.8291
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-10    3537.0366
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-18    3558.5205
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-21    3566.5422
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-22    3580.5116
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-24    3585.7419
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-27    3590.7747
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-15    3594.2496
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-25    3594.8871
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-23    3601.3299
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-14    3601.3994
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-14    3608.5778
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-12    3612.7997
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-26    3613.1399
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-16    3619.8836
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-13    3622.6806
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-22    3623.8495
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-13    3624.3224
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-14    3625.6381
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-17    3626.8317
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-17    3629.6802
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-16    3632.1299
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-11    3636.1745
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-18    3638.7542
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-20    3641.8454
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-10    3644.2876
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-09    3646.2567
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-17    3650.4714
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-12    3657.6885
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-15    3661.6546
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-11    3669.1569
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-24    3695.7877
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-19    3703.3826
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-23    3718.5158
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-16    3721.4141
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-27    3731.7742
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-06    3743.1565
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-28    3758.1208
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-04    3770.0753
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-01    3770.2244
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-27    3778.237
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-12    3779.2958
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-25    3785.6772
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-18    3790.5018
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-19    3799.2866
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-05    3805.5654
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-31    3818.5387
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-25    3821.6382
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-25    3829.2206
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-10    3833.9358
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-25    3836.4078
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-26    3836.7144
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-04    3838.0317
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-27    3841.7388
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-26    3842.196
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-03    3846.5068
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-30    3848.7887
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-05    3850.3624
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-01    3850.8604
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-02    3852.6532
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-28    3853.3932
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-06    3870.4141
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-03    3874.4132
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-14    3880.4494
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-26    3883.532
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-05    3889.7828
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-13    3893.7149
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-02    3894.4234
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-12    3894.6573
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-07    3897.5346
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-08    3911.7655
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-11    3913.7078
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-22    3913.8031
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-15    3914.376
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-26    3918.4653
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-29    3926.4179
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-10    3931.6065
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-13    3932.3273
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-19    3933.0527
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-09    3936.8966
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-06    3937.1203
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-22    3937.8815
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-20    3940.7898
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-18    3944.5932
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-20    3947.6628
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-21    3948.1354
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-04    3948.7146
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-26    3956.2032
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-19    3962.9073
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-22    3969.572
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-20    3973.9381
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-03    3976.4466
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-25    3994.6666
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-17    3996.5213
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-22    4002.0268
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-18    4004.9246
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-24    4007.2919
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-23    4011.8193
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-23    4012.3214
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-16    4014.4271
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-19    4017.4688
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-02-24    4020.6218
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-21    4021.956
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-27    4026.5637
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-13    4037.2584
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-21    4038.4597
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-28    4038.8225
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-27    4040.728
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-09    4041.0149
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-21    4041.3384
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-20    4044.0254
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-23    4044.0579
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-08    4045.433
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-01-07    4062.8349
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-29    4081.1131
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-28    4084.8558
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-19    4086.0148
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-20    4110.4037
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-30    4114.4431
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-30    4115.1322
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-01    4121.5186
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-03-31    4124.308
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-29    4150.9401
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-01    4152.101
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-23    4161.584
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-02    4168.6585
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-16    4179.9998
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-14    4182.4553
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-12-24    4182.8106
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-15    4183.4353
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-28    4192.3297
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-10    4199.9621
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-24    4212.0668
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-11    4217.8679
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-18    4234.0046
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-24    4241.0773
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-12    4252.3005
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-29    4252.6947
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-04    4258.0258
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-05    4263.3587
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-23    4277.7106
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-05    4278.3012
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-30    4290.214
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-09    4308.101
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-28    4315.5054
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-01    4319.4316
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-03    4319.4368
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-26    4325.7557
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-27    4352.3984
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-17    4357.0749
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-07    4363.8897
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-06    4368.8933
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-25    4374.0494
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-04    4392.1522
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-02    4415.5962
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-29    4472.7237
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-21    4482.6391
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-08    4486.716
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-22    4493.7981
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-08    4505.9785
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-06    4558.0248
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-20    4574.0573
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-30    4581.4964
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-03    4592.1473
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-07    4596.2638
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-09    4653.9385
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-02    4661.1735
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-08-31    4677.0422
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-02    4681.5371
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-11    4798.9833
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-09-01    4804.8621
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-10    4825.1516
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-04    4980.1098
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-05    4991.2469
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-03    5040.779
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-12    5054.3036
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-06    5059.7876
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-13    5092.8015
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-14    5097.3936
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-16    5112.3749
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-12    5123.9751
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-11    5136.8078
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-15    5137.5691
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-07    5152.8761
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-29    5184.3719
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-09    5222.4841
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-30    5222.7384
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-17    5230.419
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-19    5241.4504
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-26    5245.0197
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-08    5249.1109
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-27    5267.8588
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-10    5274.7729
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-18    5275.7727
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-19    5277.443
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-28    5280.789
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-21    5302.1348
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-01    5318.0157
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-20    5326.3319
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-22    5330.2213
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-02    5381.9432
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-18    5401.3896
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-25    5434.7936
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-24    5498.1444
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-17    5524.5596
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-25    5543.6963
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-04-23    5546.4491
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-15    5549.7758
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-16    5562.9917
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-18    5571.7789
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-15    5626.8058
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-17    5627.7652
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-13    5631.1719
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-03    5635.6485
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-19    5655.1725
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-24    5658.3559
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-06    5672.0463
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-14    5676.4593
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-16    5682.4319
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-04    5708.2934
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-05    5738.5911
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-28    5748.5225
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-20    5796.5997
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-26    5821.0857
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-27    5824.0337
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2019-05-07    5869.5386
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-23    5874.0396
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-29    5879.6991
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-22    5913.487
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-29    5928.0534
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-24    6047.795
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-14    6062.7727
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-12    6072.9791
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-21    6078.4892
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-14    6079.869
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-28    6107.6076
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-27    6128.2277
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-30    6131.3642
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-23    6166.6832
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-11    6207.1632
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-25    6222.7026
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-26    6225.0147
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-14    6252.1209
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-10-31    6252.9071
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-12    6283.4789
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-11    6284.2787
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-30    6288.2936
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-13    6290.9485
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-13    6291.0147
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-31    6293.3032
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-12    6299.2714
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-14    6304.6122
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-18    6310.0102
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-13    6311.6495
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-10    6317.5845
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-09    6319.8478
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-13    6321.4822
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-11    6323.9486
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-01    6326.316
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-12    6334.0462
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-15    6340.1869
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-29    6348.5797
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-16    6351.2625
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-19    6353.3433
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-03    6354.2995
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-13    6360.1919
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-11    6362.0272
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-12    6367.3582
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-15    6375.5075
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-02    6376.5276
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-10    6376.685
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-22    6379.0833
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-01    6379.3998
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-30    6379.9762
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-04    6382.8929
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-09    6388.8535
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-09    6393.927
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-08    6399.1874
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-10    6407.8729
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-17    6414.0105
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-21    6416.4232
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-26    6416.5305
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-05    6417.581
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-20    6418.3251
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-25    6419.549
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-23    6421.3412
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-06    6422.7625
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-19    6423.5206
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-28    6424.7343
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-27    6426.6957
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-19    6432.0774
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-22    6432.9957
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-25    6438.107
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-23    6438.8638
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-08    6440.3697
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-20    6441.8188
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-24    6446.5533
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-18    6448.5513
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-13    6458.9547
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-20    6462.0571
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-02    6466.3136
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-08    6466.9645
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-07    6473.9549
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-06    6478.9959
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-17    6480.0611
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-03    6481.0843
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-21    6482.1658
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-18    6483.8042
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-26    6485.489
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-12    6489.0484
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-16    6493.5219
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-15    6494.4976
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-16    6495.4002
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-17    6502.7161
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-14    6505.4762
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-01    6508.7579
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-14    6513.0281
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-07    6515.7451
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-16    6522.8372
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-11    6524.6881
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-10    6525.5094
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-15    6528.6224
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-16    6530.5737
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-18    6540.4034
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-27    6541.0338
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-17    6543.9392
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-06    6549.1112
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-24    6555.7032
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-10    6562.6941
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-14    6563.2021
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-29    6565.7065
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-04    6567.2087
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-15    6568.1506
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-02    6569.1736
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-05    6571.5219
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-07    6576.3334
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-04    6581.0093
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-22    6584.1557
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-06    6584.6514
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-11    6585.4815
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-01    6599.8416
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-03    6601.0725
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-30    6603.8329
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-08    6622.02
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-05    6629.1363
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-09    6632.0089
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-24    6646.4958
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-07    6655.9109
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-21    6660.0805
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-06    6667.745
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-28    6676.7634
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-26    6691.8868
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-20    6694.0527
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-22    6707.2502
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-23    6714.8067
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-27    6717.0788
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-25    6730.7092
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-19    6732.8205
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-09    6741.7765
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-21    6742.6611
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-05    6775.8313
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-11    6781.8219
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-12    6788.0829
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-10    6797.6746
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-08    6818.2082
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-01    6821.6184
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-06    6832.4936
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-17    6884.5482
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-30    6898.483
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-07    6909.6372
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-11    6913.9478
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-09    6916.0762
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-30    6938.1899
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-10    6943.8492
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-02    6962.236
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-28    6975.3463
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-07    6982.2152
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-31    6986.5
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-05    6987.2119
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-06    6989.5894
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-02    6998.5127
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-08    7017.6617
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-31    7022.3925
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-15    7024.9451
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-29    7045.3338
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-04    7100.8827
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-07    7105.9659
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-01    7107.016
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-05    7141.0566
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-10    7192.4504
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-06    7233.595
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-09    7236.2841
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-03    7236.6314
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-02    7236.9423
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-04    7247.2623
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-03    7252.201
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-04    7256.2289
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-28    7317.6978
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-04    7318.5833
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-29    7327.5205
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-03    7342.9677
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-21    7346.6049
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-12    7349.325
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-27    7366.5779
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-08    7379.4679
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-03    7389.6891
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-19    7395.3702
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-18    7409.998
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-20    7425.9746
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-22    7446.3684
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-30    7449.7914
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-16    7453.8879
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-05    7469.965
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-01    7491.1484
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-05    7491.3015
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-31    7502.6476
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-25    7525.9543
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-29    7530.9995
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-26    7531.1852
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-01    7564.2783
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-06    7572.9151
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-02    7575.9304
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-08-02    7581.6106
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-04    7582.7935
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-24    7583.1107
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-08    7610.1023
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-03    7639.7031
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-05    7646.5559
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-09    7658.5374
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-23    7672.2795
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-18    7675.353
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-07    7675.7741
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-18    7693.8791
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-17    7831.5033
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-19    7833.1737
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-23    7839.0237
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-07    7899.5663
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-31    7907.5243
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-28    7935.0471
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-27    7978.072
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-27    8004.3081
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-13    8007.8258
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-14    8024.7012
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-24    8058.3217
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-17    8072.6897
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-17    8081.7781
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-18    8084.9797
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-16    8102.3828
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-15    8109.7639
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-18    8114.1721
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-20    8119.8048
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-30    8121.8085
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-28    8158.6671
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-24    8170.7565
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-26    8171.3691
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-21    8175.8076
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-23    8180.0303
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-29    8183.3394
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-22    8201.6431
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-11    8210.8112
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-26    8222.1146
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-08    8228.8196
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-25    8232.6845
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-19    8242.6121
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-15    8247.0674
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-22    8266.0665
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-09    8271.7872
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-19    8277.994
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-16    8295.4024
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-17    8297.2588
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-16    8317.4618
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-19    8350.2081
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-20    8387.2509
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-12    8449.5836
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-20    8472.0475
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-21    8473.4111
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-25    8476.4422
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-23    8538.6037
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-25    8548.6952
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-13    8587.8977
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-14    8596.4033
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-13    8623.1956
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-20    8623.2054
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-02    8631.4466
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-12    8637.552
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-10    8652.1339
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-15    8659.7011
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-11    8722.4448
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-04    8762.662
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-14    8770.1794
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-22    8792.8392
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-21    8819.894
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-24    8863.3203
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-09    8902.8578
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-22    8914.1631
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-23    8919.2977
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-03    8949.4095
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-21    8990.2473
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-01    9020.0315
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-14    9025.8784
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-11    9059.0849
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-26    9067.2775
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-02    9130.8574
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-27    9160.5502
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-13    9162.9406
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-09    9206.1511
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-10    9242.5349
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-08    9262.515
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-28    9263.9
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-10    9277.0094
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-30    9309.7666
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-07    9312.4895
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-25    9333.2176
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-29    9372.7567
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-03    9372.8975
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-12    9445.7286
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-24    9561.08
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-06    9563.238
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-01    9583.5903
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-25    9602.2855
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-27    9611.7097
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-04    9650.6051
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-08    9710.6049
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-05    9765.6847
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-15    9799.3748
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-28    9851.0594
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-30    9893.9685
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-26    9908.168
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-24    9924.5102
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-23    10009.5048
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-16    10021.8463
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-31    10056.436
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-01    10176.4402
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-22    10272.251
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-07    10407.0417
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-11-29    10424.9261
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-27    10555.1992
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-17    10617.4863
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-28    10625.2278
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-01    10655.6536
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-17    10680.0554
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-30    10697.0446
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-18    10716.0596
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-23    10727.1991
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-21    10788.7856
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# ...
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-07    0.4759
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-26    0.4768
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-07    0.4769
# 2018-11-17    0.4769
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-09    0.4803
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-09    0.4807
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-25    0.4811
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-19    0.4821
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-01    0.485
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-14    0.4851
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-10    0.4853
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-17    0.4854
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-05    0.4859
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-02    0.4861
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-07    0.4866
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-19    0.4867
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-05    0.488
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-08    0.4884
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-04    0.489
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-23    0.4896
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-08    0.4909
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-09    0.4913
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-08    0.4915
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-30    0.495
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-11    0.4963
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-03    0.4968
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-06    0.5012
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-09    0.5015
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-11    0.5017
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-10    0.5042
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-18    0.5072
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-31    0.5073
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-07-18    0.5082
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-22    0.5088
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-12    0.509
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-04    0.5109
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-08    0.5112
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-13    0.5138
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-05    0.5184
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-21    0.5194
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-03    0.5207
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-03    0.5226
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-06    0.5264
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-18    0.5266
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-26    0.5273
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-27    0.5292
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-11-07    0.5327
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-16    0.5342
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-17    0.5343
# 2018-10-04    0.5343
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-20    0.5353
# 2018-09-28    0.5353
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-21    0.5386
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-24    0.5389
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-29    0.5396
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-13    0.5413
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-19    0.5442
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-14    0.548
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-15    0.5482
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-29    0.5528
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-12    0.5556
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-02    0.5573
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-22    0.5606
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-23    0.5736
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-10-01    0.5742
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-28    0.5755
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-27    0.5791
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-11    0.5827
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-12    0.5829
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-29    0.5833
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-09-30    0.5847
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-28    0.5873
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-18    0.5939
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-26    0.6058
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-30    0.6099
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-27    0.6102
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-31    0.6138
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-01    0.6164
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-25    0.6187
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-24    0.619
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-26    0.6191
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-10    0.6215
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-23    0.6239
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-23    0.6288
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-14    0.6304
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-25    0.6341
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-02    0.639
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-14    0.644
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-24    0.6489
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-13    0.6536
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-17    0.6574
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-03    0.6587
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-22    0.66
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-16    0.6603
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-05    0.6642
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-19    0.6647
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-17    0.6666
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-04    0.6693
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-15    0.6697
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-06    0.6706
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-08    0.6708
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-18    0.6714
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-22    0.6715
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-15    0.672
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-06    0.6731
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-09    0.6736
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-19    0.6781
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-06-07    0.6801
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-18    0.6827
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-12    0.6878
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-16    0.6891
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-20    0.6897
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-20    0.6902
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-21    0.6906
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-16    0.6908
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-21    0.6909
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-17    0.6953
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-11    0.7123
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-20    0.7145
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-13    0.7161
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-18    0.7224
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-19    0.7296
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-17    0.7321
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-15    0.7322
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-14    0.7354
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-14    0.743
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-08    0.7525
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-05    0.7527
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-16    0.7541
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-15    0.7546
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-07    0.757
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-19    0.7734
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-13    0.7776
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-09    0.7852
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-11    0.7946
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-09    0.7982
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-10    0.7993
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-12    0.8017
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-10    0.8125
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-09    0.8229
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-01    0.8247
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-08    0.8256
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-07    0.8318
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-27    0.8363
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-08    0.8408
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-02    0.8459
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-25    0.8478
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-02    0.8503
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-30    0.851
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-28    0.8511
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-20    0.861
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-23    0.8682
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-03    0.8686
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-21    0.87
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-29    0.871
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-22    0.8757
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-07    0.8804
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-06    0.8819
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-04    0.8892
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-04    0.8923
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-25    0.901
# 2018-03-02    0.901
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-03    0.902
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-01    0.9065
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-05-05    0.9091
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-26    0.9112
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-03    0.9139
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-28    0.9141
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-24    0.9158
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-04    0.9166
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-23    0.9266
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-22    0.9299
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-06    0.9331
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-27    0.9358
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-04-24    0.9365
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-24    0.9448
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-21    0.9512
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-11    0.9661
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-25    0.9808
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-21    0.9909
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-26    1.0011
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-22    1.002
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-13    1.0021
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-03-05    1.0143
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-10    1.0302
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-12    1.032
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-01    1.0332
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-23    1.0394
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-14    1.0461
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-20    1.0921
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-16    1.0982
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-17    1.0998
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-31    1.1021
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-19    1.1069
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-18    1.1084
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-15    1.1117
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-02-17    1.1441
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-27    1.1472
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-30    1.1918
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-28    1.2092
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-27    1.2125
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-26    1.2299
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-28    1.2609
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-29    1.2895
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-22    1.2994
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-23    1.3097
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-25    1.33
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-24    1.3472
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-16    1.3804
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-21    1.4215
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-18    1.4964
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-20    1.555
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-29    1.5794
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-19    1.5836
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-15    1.8065
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-14    1.8654
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-11    1.8688
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-31    1.9115
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-01    1.9216
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-10    1.9217
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-12    2.0067
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-13    2.0268
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-02    2.0549
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2017-12-30    2.0963
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-09    2.288
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-03    2.4819
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-08    2.5078
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-05    2.6657
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-06    2.667
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-07    2.7094
# Name: data_priceUsd, dtype: float64
#
#
# data_date
# 2018-01-04    2.9995
# Name: data_priceUsd, dtype: float64

# %%
# One line of code using apply(print)
single_group = crypto_data.groupby('cryptocurrency')['data_priceUsd'].apply(print)
# Out:
# data_date
# 2017-05-10    1743.723523
# 2017-05-11    1828.678209
# 2017-05-12    1776.443919
# 2017-05-13    1714.964198
# 2017-05-14    1789.278913
#                  ...
# 2019-05-03    5635.648502
# 2019-05-04    5708.293373
# 2019-05-05    5738.591093
# 2019-05-06    5672.046269
# 2019-05-07    5869.538627
# Name: bitcoin, Length: 722, dtype: float64
# data_date
# 2017-08-01    344.090146
# 2017-08-02    647.992009
# 2017-08-03    506.293007
# 2017-08-04    309.921863
# 2017-08-05    230.983515
#                  ...
# 2019-05-03    281.440627
# 2019-05-04    286.525161
# 2019-05-05    290.394285
# 2019-05-06    285.086507
# 2019-05-07    289.406309
# Name: bitcoin-cash, Length: 639, dtype: float64
# data_date
# 2017-05-09     84.915618
# 2017-05-10     88.177676
# 2017-05-11     88.432233
# 2017-05-12     88.646770
# 2017-05-13     86.503299
#                  ...
# 2019-05-03    164.020596
# 2019-05-04    163.025682
# 2019-05-05    161.789768
# 2019-05-06    165.506767
# 2019-05-07    174.858535
# Name: ethereum, Length: 722, dtype: float64
# data_date
# 2017-05-09    28.020288
# 2017-05-10    33.487730
# 2017-05-11    30.966247
# 2017-05-12    29.658289
# 2017-05-13    27.381262
#                 ...
# 2019-05-03    76.435295
# 2019-05-04    77.011308
# 2019-05-05    75.974875
# 2019-05-06    73.722948
# 2019-05-07    75.566057
# Name: litecoin, Length: 728, dtype: float64
# data_date
# 2017-05-09    0.166990
# 2017-05-10    0.179671
# 2017-05-11    0.178919
# 2017-05-12    0.195019
# 2017-05-13    0.210569
#                 ...
# 2019-05-03    0.301492
# 2019-05-04    0.301342
# 2019-05-05    0.298673
# 2019-05-06    0.297357
# 2019-05-07    0.299862
# Name: ripple, Length: 728, dtype: float64

# %%
# one line of code using apply(print)
multi_group = rounded_crypto_data.groupby(['cryptocurrency','data_priceUsd'])['data_priceUsd'].apply(print)
# Out:
# data_date
# 2017-05-13    1714.9642
# Name: (bitcoin, 1714.9642), dtype: float64
# data_date
# 2017-05-15    1742.7229
# Name: (bitcoin, 1742.7229), dtype: float64
# data_date
# 2017-05-10    1743.7235
# Name: (bitcoin, 1743.7235), dtype: float64
# data_date
# 2017-05-12    1776.4439
# Name: (bitcoin, 1776.4439), dtype: float64
# data_date
# 2017-05-14    1789.2789
# Name: (bitcoin, 1789.2789), dtype: float64
# data_date
# 2017-05-17    1802.0351
# Name: (bitcoin, 1802.0351), dtype: float64
# data_date
# 2017-05-11    1828.6782
# Name: (bitcoin, 1828.6782), dtype: float64
# data_date
# 2017-05-18    1840.5017
# Name: (bitcoin, 1840.5017), dtype: float64
# data_date
# 2017-05-19    1932.285
# Name: (bitcoin, 1932.285), dtype: float64
# data_date
# 2017-07-16    1958.249
# Name: (bitcoin, 1958.249), dtype: float64
# data_date
# 2017-05-20    1988.9614
# Name: (bitcoin, 1988.9614), dtype: float64
# data_date
# 2017-05-21    2041.0432
# Name: (bitcoin, 2041.0432), dtype: float64
# data_date
# 2017-05-27    2046.892
# Name: (bitcoin, 2046.892), dtype: float64
# data_date
# 2017-07-17    2071.9572
# Name: (bitcoin, 2071.9572), dtype: float64
# data_date
# 2017-07-15    2096.0676
# Name: (bitcoin, 2096.0676), dtype: float64
# data_date
# 2017-05-22    2132.6159
# Name: (bitcoin, 2132.6159), dtype: float64
# data_date
# 2017-05-28    2155.2271
# Name: (bitcoin, 2155.2271), dtype: float64
# data_date
# 2017-05-23    2192.001
# Name: (bitcoin, 2192.001), dtype: float64
# data_date
# 2017-05-29    2212.0498
# Name: (bitcoin, 2212.0498), dtype: float64
# data_date
# 2017-05-30    2250.8593
# Name: (bitcoin, 2250.8593), dtype: float64
# data_date
# 2017-07-18    2288.2415
# Name: (bitcoin, 2288.2415), dtype: float64
# data_date
# 2017-07-14    2291.0771
# Name: (bitcoin, 2291.0771), dtype: float64
# data_date
# 2017-07-19    2327.1945
# Name: (bitcoin, 2327.1945), dtype: float64
# data_date
# 2017-07-11    2346.6942
# Name: (bitcoin, 2346.6942), dtype: float64
# data_date
# 2017-07-12    2354.4149
# Name: (bitcoin, 2354.4149), dtype: float64
# data_date
# 2017-06-15    2357.0754
# Name: (bitcoin, 2357.0754), dtype: float64
# data_date
# 2017-06-01    2372.2884
# Name: (bitcoin, 2372.2884), dtype: float64
# data_date
# 2017-05-26    2372.6741
# Name: (bitcoin, 2372.6741), dtype: float64
# data_date
# 2017-07-13    2378.7925
# Name: (bitcoin, 2378.7925), dtype: float64
# data_date
# 2017-06-02    2407.7554
# Name: (bitcoin, 2407.7554), dtype: float64
# data_date
# 2017-06-27    2417.8674
# Name: (bitcoin, 2417.8674), dtype: float64
# data_date
# 2017-07-01    2451.2132
# Name: (bitcoin, 2451.2132), dtype: float64
# data_date
# 2017-07-10    2453.3487
# Name: (bitcoin, 2453.3487), dtype: float64
# data_date
# 2017-06-16    2457.4543
# Name: (bitcoin, 2457.4543), dtype: float64
# data_date
# 2017-07-02    2459.3475
# Name: (bitcoin, 2459.3475), dtype: float64
# data_date
# 2017-06-26    2466.3221
# Name: (bitcoin, 2466.3221), dtype: float64
# data_date
# 2017-07-20    2498.8424
# Name: (bitcoin, 2498.8424), dtype: float64
# data_date
# 2017-06-03    2500.431
# Name: (bitcoin, 2500.431), dtype: float64
# data_date
# 2017-06-04    2505.2799
# Name: (bitcoin, 2505.2799), dtype: float64
# data_date
# 2017-07-08    2520.6249
# Name: (bitcoin, 2520.6249), dtype: float64
# data_date
# 2017-07-26    2531.3779
# Name: (bitcoin, 2531.3779), dtype: float64
# data_date
# 2017-06-30    2539.8604
# Name: (bitcoin, 2539.8604), dtype: float64
# data_date
# 2017-07-03    2541.0371
# Name: (bitcoin, 2541.0371), dtype: float64
# data_date
# 2017-06-28    2543.7378
# Name: (bitcoin, 2543.7378), dtype: float64
# data_date
# 2017-07-09    2545.2185
# Name: (bitcoin, 2545.2185), dtype: float64
# data_date
# 2017-05-25    2545.8947
# Name: (bitcoin, 2545.8947), dtype: float64
# data_date
# 2017-07-07    2553.6769
# Name: (bitcoin, 2553.6769), dtype: float64
# data_date
# 2017-06-17    2566.4387
# Name: (bitcoin, 2566.4387), dtype: float64
# data_date
# 2017-06-29    2566.8513
# Name: (bitcoin, 2566.8513), dtype: float64
# data_date
# 2017-06-25    2569.0037
# Name: (bitcoin, 2569.0037), dtype: float64
# data_date
# 2017-06-18    2570.4721
# Name: (bitcoin, 2570.4721), dtype: float64
# data_date
# 2017-06-19    2570.7849
# Name: (bitcoin, 2570.7849), dtype: float64
# data_date
# 2017-06-05    2588.9515
# Name: (bitcoin, 2588.9515), dtype: float64
# data_date
# 2017-07-05    2590.6413
# Name: (bitcoin, 2590.6413), dtype: float64
# data_date
# 2017-07-27    2597.7125
# Name: (bitcoin, 2597.7125), dtype: float64
# data_date
# 2017-07-06    2606.4737
# Name: (bitcoin, 2606.4737), dtype: float64
# data_date
# 2017-07-04    2612.2555
# Name: (bitcoin, 2612.2555), dtype: float64
# data_date
# 2017-07-25    2639.382
# Name: (bitcoin, 2639.382), dtype: float64
# data_date
# 2017-06-14    2644.4253
# Name: (bitcoin, 2644.4253), dtype: float64
# data_date
# 2017-06-24    2671.631
# Name: (bitcoin, 2671.631), dtype: float64
# data_date
# 2017-06-20    2675.4288
# Name: (bitcoin, 2675.4288), dtype: float64
# data_date
# 2017-06-22    2689.3516
# Name: (bitcoin, 2689.3516), dtype: float64
# data_date
# 2017-06-13    2697.9214
# Name: (bitcoin, 2697.9214), dtype: float64
# data_date
# 2017-07-30    2707.2755
# Name: (bitcoin, 2707.2755), dtype: float64
# data_date
# 2017-06-21    2714.1539
# Name: (bitcoin, 2714.1539), dtype: float64
# data_date
# 2017-07-21    2725.3905
# Name: (bitcoin, 2725.3905), dtype: float64
# data_date
# 2017-08-02    2727.949
# Name: (bitcoin, 2727.949), dtype: float64
# data_date
# 2017-06-23    2734.3678
# Name: (bitcoin, 2734.3678), dtype: float64
# data_date
# 2017-07-29    2743.7321
# Name: (bitcoin, 2743.7321), dtype: float64
# data_date
# 2017-06-08    2746.1159
# Name: (bitcoin, 2746.1159), dtype: float64
# data_date
# 2017-08-03    2757.4284
# Name: (bitcoin, 2757.4284), dtype: float64
# data_date
# 2017-07-24    2758.0041
# Name: (bitcoin, 2758.0041), dtype: float64
# data_date
# 2017-07-28    2759.9125
# Name: (bitcoin, 2759.9125), dtype: float64
# data_date
# 2017-07-23    2774.0822
# Name: (bitcoin, 2774.0822), dtype: float64
# data_date
# 2017-06-12    2782.4335
# Name: (bitcoin, 2782.4335), dtype: float64
# data_date
# 2017-07-31    2787.8712
# Name: (bitcoin, 2787.8712), dtype: float64
# data_date
# 2017-07-22    2789.302
# Name: (bitcoin, 2789.302), dtype: float64
# data_date
# 2017-08-01    2793.5617
# Name: (bitcoin, 2793.5617), dtype: float64
# data_date
# 2017-06-07    2807.9937
# Name: (bitcoin, 2807.9937), dtype: float64
# data_date
# 2017-06-09    2817.291
# Name: (bitcoin, 2817.291), dtype: float64
# data_date
# 2017-06-06    2819.7413
# Name: (bitcoin, 2819.7413), dtype: float64
# data_date
# 2017-08-04    2842.1135
# Name: (bitcoin, 2842.1135), dtype: float64
# data_date
# 2017-06-10    2846.7352
# Name: (bitcoin, 2846.7352), dtype: float64
# data_date
# 2017-06-11    2894.7766
# Name: (bitcoin, 2894.7766), dtype: float64
# data_date
# 2017-08-05    3161.3145
# Name: (bitcoin, 3161.3145), dtype: float64
# data_date
# 2017-08-06    3234.1647
# Name: (bitcoin, 3234.1647), dtype: float64
# data_date
# 2018-12-15    3239.2274
# Name: (bitcoin, 3239.2274), dtype: float64
# data_date
# 2018-12-16    3281.677
# Name: (bitcoin, 3281.677), dtype: float64
# data_date
# 2018-12-14    3282.419
# Name: (bitcoin, 3282.419), dtype: float64
# data_date
# 2017-08-07    3312.5353
# Name: (bitcoin, 3312.5353), dtype: float64
# data_date
# 2017-08-09    3353.1546
# Name: (bitcoin, 3353.1546), dtype: float64
# data_date
# 2018-12-17    3399.8989
# Name: (bitcoin, 3399.8989), dtype: float64
# data_date
# 2019-02-07    3401.0456
# Name: (bitcoin, 3401.0456), dtype: float64
# data_date
# 2019-02-06    3401.5059
# Name: (bitcoin, 3401.5059), dtype: float64
# data_date
# 2018-12-07    3401.8835
# Name: (bitcoin, 3401.8835), dtype: float64
# data_date
# 2017-08-10    3403.6714
# Name: (bitcoin, 3403.6714), dtype: float64
# data_date
# 2018-12-13    3413.2751
# Name: (bitcoin, 3413.2751), dtype: float64
# data_date
# 2017-09-15    3414.1288
# Name: (bitcoin, 3414.1288), dtype: float64
# data_date
# 2018-12-08    3423.8151
# Name: (bitcoin, 3423.8151), dtype: float64
# data_date
# 2019-01-29    3426.6454
# Name: (bitcoin, 3426.6454), dtype: float64
# data_date
# 2017-08-08    3427.0901
# Name: (bitcoin, 3427.0901), dtype: float64
# data_date
# 2018-12-11    3435.5312
# Name: (bitcoin, 3435.5312), dtype: float64
# data_date
# 2018-12-12    3453.5157
# Name: (bitcoin, 3453.5157), dtype: float64
# data_date
# 2019-02-01    3455.2242
# Name: (bitcoin, 3455.2242), dtype: float64
# data_date
# 2019-02-04    3457.9624
# Name: (bitcoin, 3457.9624), dtype: float64
# data_date
# 2019-01-30    3458.6496
# Name: (bitcoin, 3458.6496), dtype: float64
# data_date
# 2019-02-05    3459.1958
# Name: (bitcoin, 3459.1958), dtype: float64
# data_date
# 2019-01-31    3462.7295
# Name: (bitcoin, 3462.7295), dtype: float64
# data_date
# 2019-01-28    3476.0724
# Name: (bitcoin, 3476.0724), dtype: float64
# data_date
# 2019-02-03    3476.106
# Name: (bitcoin, 3476.106), dtype: float64
# data_date
# 2019-02-02    3477.037
# Name: (bitcoin, 3477.037), dtype: float64
# data_date
# 2019-02-08    3489.1396
# Name: (bitcoin, 3489.1396), dtype: float64
# data_date
# 2017-08-11    3518.3843
# Name: (bitcoin, 3518.3843), dtype: float64
# data_date
# 2018-12-09    3534.8291
# Name: (bitcoin, 3534.8291), dtype: float64
# data_date
# 2018-12-10    3537.0366
# Name: (bitcoin, 3537.0366), dtype: float64
# data_date
# 2018-12-18    3558.5205
# Name: (bitcoin, 3558.5205), dtype: float64
# data_date
# 2019-01-21    3566.5422
# Name: (bitcoin, 3566.5422), dtype: float64
# data_date
# 2019-01-22    3580.5116
# Name: (bitcoin, 3580.5116), dtype: float64
# data_date
# 2019-01-24    3585.7419
# Name: (bitcoin, 3585.7419), dtype: float64
# data_date
# 2019-01-27    3590.7747
# Name: (bitcoin, 3590.7747), dtype: float64
# data_date
# 2019-02-15    3594.2496
# Name: (bitcoin, 3594.2496), dtype: float64
# data_date
# 2019-01-25    3594.8871
# Name: (bitcoin, 3594.8871), dtype: float64
# data_date
# 2019-01-23    3601.3299
# Name: (bitcoin, 3601.3299), dtype: float64
# data_date
# 2019-02-14    3601.3994
# Name: (bitcoin, 3601.3994), dtype: float64
# data_date
# 2019-01-14    3608.5778
# Name: (bitcoin, 3608.5778), dtype: float64
# data_date
# 2019-02-12    3612.7997
# Name: (bitcoin, 3612.7997), dtype: float64
# data_date
# 2019-01-26    3613.1399
# Name: (bitcoin, 3613.1399), dtype: float64
# data_date
# 2019-02-16    3619.8836
# Name: (bitcoin, 3619.8836), dtype: float64
# data_date
# 2019-02-13    3622.6806
# Name: (bitcoin, 3622.6806), dtype: float64
# data_date
# 2017-09-22    3623.8495
# Name: (bitcoin, 3623.8495), dtype: float64
# data_date
# 2019-01-13    3624.3224
# Name: (bitcoin, 3624.3224), dtype: float64
# data_date
# 2017-09-14    3625.6381
# Name: (bitcoin, 3625.6381), dtype: float64
# data_date
# 2019-01-17    3626.8317
# Name: (bitcoin, 3626.8317), dtype: float64
# data_date
# 2019-02-17    3629.6802
# Name: (bitcoin, 3629.6802), dtype: float64
# data_date
# 2019-01-16    3632.1299
# Name: (bitcoin, 3632.1299), dtype: float64
# data_date
# 2019-02-11    3636.1745
# Name: (bitcoin, 3636.1745), dtype: float64
# data_date
# 2019-01-18    3638.7542
# Name: (bitcoin, 3638.7542), dtype: float64
# data_date
# 2019-01-20    3641.8454
# Name: (bitcoin, 3641.8454), dtype: float64
# data_date
# 2019-02-10    3644.2876
# Name: (bitcoin, 3644.2876), dtype: float64
# data_date
# 2019-02-09    3646.2567
# Name: (bitcoin, 3646.2567), dtype: float64
# data_date
# 2017-09-17    3650.4714
# Name: (bitcoin, 3650.4714), dtype: float64
# data_date
# 2019-01-12    3657.6885
# Name: (bitcoin, 3657.6885), dtype: float64
# data_date
# 2019-01-15    3661.6546
# Name: (bitcoin, 3661.6546), dtype: float64
# data_date
# 2019-01-11    3669.1569
# Name: (bitcoin, 3669.1569), dtype: float64
# data_date
# 2017-09-24    3695.7877
# Name: (bitcoin, 3695.7877), dtype: float64
# data_date
# 2019-01-19    3703.3826
# Name: (bitcoin, 3703.3826), dtype: float64
# data_date
# 2017-09-23    3718.5158
# Name: (bitcoin, 3718.5158), dtype: float64
# data_date
# 2017-09-16    3721.4141
# Name: (bitcoin, 3721.4141), dtype: float64
# data_date
# 2018-11-27    3731.7742
# Name: (bitcoin, 3731.7742), dtype: float64
# data_date
# 2018-12-06    3743.1565
# Name: (bitcoin, 3743.1565), dtype: float64
# data_date
# 2018-12-28    3758.1208
# Name: (bitcoin, 3758.1208), dtype: float64
# data_date
# 2019-03-04    3770.0753
# Name: (bitcoin, 3770.0753), dtype: float64
# data_date
# 2019-01-01    3770.2244
# Name: (bitcoin, 3770.2244), dtype: float64
# data_date
# 2018-12-27    3778.237
# Name: (bitcoin, 3778.237), dtype: float64
# data_date
# 2017-08-12    3779.2958
# Name: (bitcoin, 3779.2958), dtype: float64
# data_date
# 2018-11-25    3785.6772
# Name: (bitcoin, 3785.6772), dtype: float64
# data_date
# 2019-02-18    3790.5018
# Name: (bitcoin, 3790.5018), dtype: float64
# data_date
# 2018-12-19    3799.2866
# Name: (bitcoin, 3799.2866), dtype: float64
# data_date
# 2019-03-05    3805.5654
# Name: (bitcoin, 3805.5654), dtype: float64
# data_date
# 2018-12-31    3818.5387
# Name: (bitcoin, 3818.5387), dtype: float64
# data_date
# 2017-09-25    3821.6382
# Name: (bitcoin, 3821.6382), dtype: float64
# data_date
# 2019-02-25    3829.2206
# Name: (bitcoin, 3829.2206), dtype: float64
# data_date
# 2019-01-10    3833.9358
# Name: (bitcoin, 3833.9358), dtype: float64
# data_date
# 2018-12-25    3836.4078
# Name: (bitcoin, 3836.4078), dtype: float64
# data_date
# 2019-02-26    3836.7144
# Name: (bitcoin, 3836.7144), dtype: float64
# data_date
# 2019-01-04    3838.0317
# Name: (bitcoin, 3838.0317), dtype: float64
# data_date
# 2019-02-27    3841.7388
# Name: (bitcoin, 3841.7388), dtype: float64
# data_date
# 2018-12-26    3842.196
# Name: (bitcoin, 3842.196), dtype: float64
# data_date
# 2019-03-03    3846.5068
# Name: (bitcoin, 3846.5068), dtype: float64
# data_date
# 2018-12-30    3848.7887
# Name: (bitcoin, 3848.7887), dtype: float64
# data_date
# 2018-12-05    3850.3624
# Name: (bitcoin, 3850.3624), dtype: float64
# data_date
# 2019-03-01    3850.8604
# Name: (bitcoin, 3850.8604), dtype: float64
# data_date
# 2019-03-02    3852.6532
# Name: (bitcoin, 3852.6532), dtype: float64
# data_date
# 2019-02-28    3853.3932
# Name: (bitcoin, 3853.3932), dtype: float64
# data_date
# 2019-03-06    3870.4141
# Name: (bitcoin, 3870.4141), dtype: float64
# data_date
# 2019-01-03    3874.4132
# Name: (bitcoin, 3874.4132), dtype: float64
# data_date
# 2019-03-14    3880.4494
# Name: (bitcoin, 3880.4494), dtype: float64
# data_date
# 2018-11-26    3883.532
# Name: (bitcoin, 3883.532), dtype: float64
# data_date
# 2019-01-05    3889.7828
# Name: (bitcoin, 3889.7828), dtype: float64
# data_date
# 2019-03-13    3893.7149
# Name: (bitcoin, 3893.7149), dtype: float64
# data_date
# 2019-01-02    3894.4234
# Name: (bitcoin, 3894.4234), dtype: float64
# data_date
# 2019-03-12    3894.6573
# Name: (bitcoin, 3894.6573), dtype: float64
# data_date
# 2019-03-07    3897.5346
# Name: (bitcoin, 3897.5346), dtype: float64
# data_date
# 2019-03-08    3911.7655
# Name: (bitcoin, 3911.7655), dtype: float64
# data_date
# 2019-03-11    3913.7078
# Name: (bitcoin, 3913.7078), dtype: float64
# data_date
# 2018-12-22    3913.8031
# Name: (bitcoin, 3913.8031), dtype: float64
# data_date
# 2019-03-15    3914.376
# Name: (bitcoin, 3914.376), dtype: float64
# data_date
# 2017-09-26    3918.4653
# Name: (bitcoin, 3918.4653), dtype: float64
# data_date
# 2018-12-29    3926.4179
# Name: (bitcoin, 3926.4179), dtype: float64
# data_date
# 2019-03-10    3931.6065
# Name: (bitcoin, 3931.6065), dtype: float64
# data_date
# 2017-09-13    3932.3273
# Name: (bitcoin, 3932.3273), dtype: float64
# data_date
# 2019-02-19    3933.0527
# Name: (bitcoin, 3933.0527), dtype: float64
# data_date
# 2019-03-09    3936.8966
# Name: (bitcoin, 3936.8966), dtype: float64
# data_date
# 2019-01-06    3937.1203
# Name: (bitcoin, 3937.1203), dtype: float64
# data_date
# 2017-08-22    3937.8815
# Name: (bitcoin, 3937.8815), dtype: float64
# data_date
# 2017-09-20    3940.7898
# Name: (bitcoin, 3940.7898), dtype: float64
# data_date
# 2017-09-18    3944.5932
# Name: (bitcoin, 3944.5932), dtype: float64
# data_date
# 2019-02-20    3947.6628
# Name: (bitcoin, 3947.6628), dtype: float64
# data_date
# 2019-02-21    3948.1354
# Name: (bitcoin, 3948.1354), dtype: float64
# data_date
# 2018-12-04    3948.7146
# Name: (bitcoin, 3948.7146), dtype: float64
# data_date
# 2019-03-26    3956.2032
# Name: (bitcoin, 3956.2032), dtype: float64
# data_date
# 2017-09-19    3962.9073
# Name: (bitcoin, 3962.9073), dtype: float64
# data_date
# 2019-02-22    3969.572
# Name: (bitcoin, 3969.572), dtype: float64
# data_date
# 2018-12-20    3973.9381
# Name: (bitcoin, 3973.9381), dtype: float64
# data_date
# 2018-12-03    3976.4466
# Name: (bitcoin, 3976.4466), dtype: float64
# data_date
# 2019-03-25    3994.6666
# Name: (bitcoin, 3994.6666), dtype: float64
# data_date
# 2019-03-17    3996.5213
# Name: (bitcoin, 3996.5213), dtype: float64
# data_date
# 2019-03-22    4002.0268
# Name: (bitcoin, 4002.0268), dtype: float64
# data_date
# 2019-03-18    4004.9246
# Name: (bitcoin, 4004.9246), dtype: float64
# data_date
# 2019-03-24    4007.2919
# Name: (bitcoin, 4007.2919), dtype: float64
# data_date
# 2019-03-23    4011.8193
# Name: (bitcoin, 4011.8193), dtype: float64
# data_date
# 2019-02-23    4012.3214
# Name: (bitcoin, 4012.3214), dtype: float64
# data_date
# 2019-03-16    4014.4271
# Name: (bitcoin, 4014.4271), dtype: float64
# data_date
# 2019-03-19    4017.4688
# Name: (bitcoin, 4017.4688), dtype: float64
# data_date
# 2019-02-24    4020.6218
# Name: (bitcoin, 4020.6218), dtype: float64
# data_date
# 2018-12-21    4021.956
# Name: (bitcoin, 4021.956), dtype: float64
# data_date
# 2019-03-27    4026.5637
# Name: (bitcoin, 4026.5637), dtype: float64
# data_date
# 2017-08-13    4037.2584
# Name: (bitcoin, 4037.2584), dtype: float64
# data_date
# 2019-03-21    4038.4597
# Name: (bitcoin, 4038.4597), dtype: float64
# data_date
# 2019-03-28    4038.8225
# Name: (bitcoin, 4038.8225), dtype: float64
# data_date
# 2017-09-27    4040.728
# Name: (bitcoin, 4040.728), dtype: float64
# data_date
# 2019-01-09    4041.0149
# Name: (bitcoin, 4041.0149), dtype: float64
# data_date
# 2017-08-21    4041.3384
# Name: (bitcoin, 4041.3384), dtype: float64
# data_date
# 2019-03-20    4044.0254
# Name: (bitcoin, 4044.0254), dtype: float64
# data_date
# 2018-12-23    4044.0579
# Name: (bitcoin, 4044.0579), dtype: float64
# data_date
# 2019-01-08    4045.433
# Name: (bitcoin, 4045.433), dtype: float64
# data_date
# 2019-01-07    4062.8349
# Name: (bitcoin, 4062.8349), dtype: float64
# data_date
# 2019-03-29    4081.1131
# Name: (bitcoin, 4081.1131), dtype: float64
# data_date
# 2018-11-28    4084.8558
# Name: (bitcoin, 4084.8558), dtype: float64
# data_date
# 2017-08-19    4086.0148
# Name: (bitcoin, 4086.0148), dtype: float64
# data_date
# 2017-08-20    4110.4037
# Name: (bitcoin, 4110.4037), dtype: float64
# data_date
# 2019-03-30    4114.4431
# Name: (bitcoin, 4114.4431), dtype: float64
# data_date
# 2018-11-30    4115.1322
# Name: (bitcoin, 4115.1322), dtype: float64
# data_date
# 2018-12-01    4121.5186
# Name: (bitcoin, 4121.5186), dtype: float64
# data_date
# 2019-03-31    4124.308
# Name: (bitcoin, 4124.308), dtype: float64
# data_date
# 2017-09-29    4150.9401
# Name: (bitcoin, 4150.9401), dtype: float64
# data_date
# 2019-04-01    4152.101
# Name: (bitcoin, 4152.101), dtype: float64
# data_date
# 2017-08-23    4161.584
# Name: (bitcoin, 4161.584), dtype: float64
# data_date
# 2018-12-02    4168.6585
# Name: (bitcoin, 4168.6585), dtype: float64
# data_date
# 2017-08-16    4179.9998
# Name: (bitcoin, 4179.9998), dtype: float64
# data_date
# 2017-08-14    4182.4553
# Name: (bitcoin, 4182.4553), dtype: float64
# data_date
# 2018-12-24    4182.8106
# Name: (bitcoin, 4182.8106), dtype: float64
# data_date
# 2017-08-15    4183.4353
# Name: (bitcoin, 4183.4353), dtype: float64
# data_date
# 2017-09-28    4192.3297
# Name: (bitcoin, 4192.3297), dtype: float64
# data_date
# 2017-09-10    4199.9621
# Name: (bitcoin, 4199.9621), dtype: float64
# data_date
# 2017-08-24    4212.0668
# Name: (bitcoin, 4212.0668), dtype: float64
# data_date
# 2017-09-11    4217.8679
# Name: (bitcoin, 4217.8679), dtype: float64
# data_date
# 2017-08-18    4234.0046
# Name: (bitcoin, 4234.0046), dtype: float64
# data_date
# 2018-11-24    4241.0773
# Name: (bitcoin, 4241.0773), dtype: float64
# data_date
# 2017-09-12    4252.3005
# Name: (bitcoin, 4252.3005), dtype: float64
# data_date
# 2018-11-29    4252.6947
# Name: (bitcoin, 4252.6947), dtype: float64
# data_date
# 2017-10-04    4258.0258
# Name: (bitcoin, 4258.0258), dtype: float64
# data_date
# 2017-10-05    4263.3587
# Name: (bitcoin, 4263.3587), dtype: float64
# data_date
# 2018-11-23    4277.7106
# Name: (bitcoin, 4277.7106), dtype: float64
# data_date
# 2017-09-05    4278.3012
# Name: (bitcoin, 4278.3012), dtype: float64
# data_date
# 2017-09-30    4290.214
# Name: (bitcoin, 4290.214), dtype: float64
# data_date
# 2017-09-09    4308.101
# Name: (bitcoin, 4308.101), dtype: float64
# data_date
# 2017-08-28    4315.5054
# Name: (bitcoin, 4315.5054), dtype: float64
# data_date
# 2017-10-01    4319.4316
# Name: (bitcoin, 4319.4316), dtype: float64
# data_date
# 2017-10-03    4319.4368
# Name: (bitcoin, 4319.4368), dtype: float64
# data_date
# 2017-08-26    4325.7557
# Name: (bitcoin, 4325.7557), dtype: float64
# data_date
# 2017-08-27    4352.3984
# Name: (bitcoin, 4352.3984), dtype: float64
# data_date
# 2017-08-17    4357.0749
# Name: (bitcoin, 4357.0749), dtype: float64
# data_date
# 2017-10-07    4363.8897
# Name: (bitcoin, 4363.8897), dtype: float64
# data_date
# 2017-10-06    4368.8933
# Name: (bitcoin, 4368.8933), dtype: float64
# data_date
# 2017-08-25    4374.0494
# Name: (bitcoin, 4374.0494), dtype: float64
# data_date
# 2017-09-04    4392.1522
# Name: (bitcoin, 4392.1522), dtype: float64
# data_date
# 2017-10-02    4415.5962
# Name: (bitcoin, 4415.5962), dtype: float64
# data_date
# 2017-08-29    4472.7237
# Name: (bitcoin, 4472.7237), dtype: float64
# data_date
# 2018-11-21    4482.6391
# Name: (bitcoin, 4482.6391), dtype: float64
# data_date
# 2017-09-08    4486.716
# Name: (bitcoin, 4486.716), dtype: float64
# data_date
# 2018-11-22    4493.7981
# Name: (bitcoin, 4493.7981), dtype: float64
# data_date
# 2017-10-08    4505.9785
# Name: (bitcoin, 4505.9785), dtype: float64
# data_date
# 2017-09-06    4558.0248
# Name: (bitcoin, 4558.0248), dtype: float64
# data_date
# 2018-11-20    4574.0573
# Name: (bitcoin, 4574.0573), dtype: float64
# data_date
# 2017-08-30    4581.4964
# Name: (bitcoin, 4581.4964), dtype: float64
# data_date
# 2017-09-03    4592.1473
# Name: (bitcoin, 4592.1473), dtype: float64
# data_date
# 2017-09-07    4596.2638
# Name: (bitcoin, 4596.2638), dtype: float64
# data_date
# 2017-10-09    4653.9385
# Name: (bitcoin, 4653.9385), dtype: float64
# data_date
# 2019-04-02    4661.1735
# Name: (bitcoin, 4661.1735), dtype: float64
# data_date
# 2017-08-31    4677.0422
# Name: (bitcoin, 4677.0422), dtype: float64
# data_date
# 2017-09-02    4681.5371
# Name: (bitcoin, 4681.5371), dtype: float64
# data_date
# 2017-10-11    4798.9833
# Name: (bitcoin, 4798.9833), dtype: float64
# data_date
# 2017-09-01    4804.8621
# Name: (bitcoin, 4804.8621), dtype: float64
# data_date
# 2017-10-10    4825.1516
# Name: (bitcoin, 4825.1516), dtype: float64
# data_date
# 2019-04-04    4980.1098
# Name: (bitcoin, 4980.1098), dtype: float64
# data_date
# 2019-04-05    4991.2469
# Name: (bitcoin, 4991.2469), dtype: float64
# data_date
# 2019-04-03    5040.779
# Name: (bitcoin, 5040.779), dtype: float64
# data_date
# 2019-04-12    5054.3036
# Name: (bitcoin, 5054.3036), dtype: float64
# data_date
# 2019-04-06    5059.7876
# Name: (bitcoin, 5059.7876), dtype: float64
# data_date
# 2019-04-13    5092.8015
# Name: (bitcoin, 5092.8015), dtype: float64
# data_date
# 2019-04-14    5097.3936
# Name: (bitcoin, 5097.3936), dtype: float64
# data_date
# 2019-04-16    5112.3749
# Name: (bitcoin, 5112.3749), dtype: float64
# data_date
# 2017-10-12    5123.9751
# Name: (bitcoin, 5123.9751), dtype: float64
# data_date
# 2019-04-11    5136.8078
# Name: (bitcoin, 5136.8078), dtype: float64
# data_date
# 2019-04-15    5137.5691
# Name: (bitcoin, 5137.5691), dtype: float64
# data_date
# 2019-04-07    5152.8761
# Name: (bitcoin, 5152.8761), dtype: float64
# data_date
# 2019-04-29    5184.3719
# Name: (bitcoin, 5184.3719), dtype: float64
# data_date
# 2019-04-09    5222.4841
# Name: (bitcoin, 5222.4841), dtype: float64
# data_date
# 2019-04-30    5222.7384
# Name: (bitcoin, 5222.7384), dtype: float64
# data_date
# 2019-04-17    5230.419
# Name: (bitcoin, 5230.419), dtype: float64
# data_date
# 2018-11-19    5241.4504
# Name: (bitcoin, 5241.4504), dtype: float64
# data_date
# 2019-04-26    5245.0197
# Name: (bitcoin, 5245.0197), dtype: float64
# data_date
# 2019-04-08    5249.1109
# Name: (bitcoin, 5249.1109), dtype: float64
# data_date
# 2019-04-27    5267.8588
# Name: (bitcoin, 5267.8588), dtype: float64
# data_date
# 2019-04-10    5274.7729
# Name: (bitcoin, 5274.7729), dtype: float64
# data_date
# 2019-04-18    5275.7727
# Name: (bitcoin, 5275.7727), dtype: float64
# data_date
# 2019-04-19    5277.443
# Name: (bitcoin, 5277.443), dtype: float64
# data_date
# 2019-04-28    5280.789
# Name: (bitcoin, 5280.789), dtype: float64
# data_date
# 2019-04-21    5302.1348
# Name: (bitcoin, 5302.1348), dtype: float64
# data_date
# 2019-05-01    5318.0157
# Name: (bitcoin, 5318.0157), dtype: float64
# data_date
# 2019-04-20    5326.3319
# Name: (bitcoin, 5326.3319), dtype: float64
# data_date
# 2019-04-22    5330.2213
# Name: (bitcoin, 5330.2213), dtype: float64
# data_date
# 2019-05-02    5381.9432
# Name: (bitcoin, 5381.9432), dtype: float64
# data_date
# 2017-10-18    5401.3896
# Name: (bitcoin, 5401.3896), dtype: float64
# data_date
# 2019-04-25    5434.7936
# Name: (bitcoin, 5434.7936), dtype: float64
# data_date
# 2019-04-24    5498.1444
# Name: (bitcoin, 5498.1444), dtype: float64
# data_date
# 2018-11-17    5524.5596
# Name: (bitcoin, 5524.5596), dtype: float64
# data_date
# 2017-10-25    5543.6963
# Name: (bitcoin, 5543.6963), dtype: float64
# data_date
# 2019-04-23    5546.4491
# Name: (bitcoin, 5546.4491), dtype: float64
# data_date
# 2018-11-15    5549.7758
# Name: (bitcoin, 5549.7758), dtype: float64
# data_date
# 2018-11-16    5562.9917
# Name: (bitcoin, 5562.9917), dtype: float64
# data_date
# 2018-11-18    5571.7789
# Name: (bitcoin, 5571.7789), dtype: float64
# data_date
# 2017-10-15    5626.8058
# Name: (bitcoin, 5626.8058), dtype: float64
# data_date
# 2017-10-17    5627.7652
# Name: (bitcoin, 5627.7652), dtype: float64
# data_date
# 2017-10-13    5631.1719
# Name: (bitcoin, 5631.1719), dtype: float64
# data_date
# 2019-05-03    5635.6485
# Name: (bitcoin, 5635.6485), dtype: float64
# data_date
# 2017-10-19    5655.1725
# Name: (bitcoin, 5655.1725), dtype: float64
# data_date
# 2017-10-24    5658.3559
# Name: (bitcoin, 5658.3559), dtype: float64
# data_date
# 2019-05-06    5672.0463
# Name: (bitcoin, 5672.0463), dtype: float64
# data_date
# 2017-10-14    5676.4593
# Name: (bitcoin, 5676.4593), dtype: float64
# data_date
# 2017-10-16    5682.4319
# Name: (bitcoin, 5682.4319), dtype: float64
# data_date
# 2019-05-04    5708.2934
# Name: (bitcoin, 5708.2934), dtype: float64
# data_date
# 2019-05-05    5738.5911
# Name: (bitcoin, 5738.5911), dtype: float64
# data_date
# 2017-10-28    5748.5225
# Name: (bitcoin, 5748.5225), dtype: float64
# data_date
# 2017-10-20    5796.5997
# Name: (bitcoin, 5796.5997), dtype: float64
# data_date
# 2017-10-26    5821.0857
# Name: (bitcoin, 5821.0857), dtype: float64
# data_date
# 2017-10-27    5824.0337
# Name: (bitcoin, 5824.0337), dtype: float64
# data_date
# 2019-05-07    5869.5386
# Name: (bitcoin, 5869.5386), dtype: float64
# data_date
# 2017-10-23    5874.0396
# Name: (bitcoin, 5874.0396), dtype: float64
# data_date
# 2017-10-29    5879.6991
# Name: (bitcoin, 5879.6991), dtype: float64
# data_date
# 2017-10-22    5913.487
# Name: (bitcoin, 5913.487), dtype: float64
# data_date
# 2018-06-29    5928.0534
# Name: (bitcoin, 5928.0534), dtype: float64
# data_date
# 2018-06-24    6047.795
# Name: (bitcoin, 6047.795), dtype: float64
# data_date
# 2018-08-14    6062.7727
# Name: (bitcoin, 6062.7727), dtype: float64
# data_date
# 2017-11-12    6072.9791
# Name: (bitcoin, 6072.9791), dtype: float64
# data_date
# 2017-10-21    6078.4892
# Name: (bitcoin, 6078.4892), dtype: float64
# data_date
# 2018-11-14    6079.869
# Name: (bitcoin, 6079.869), dtype: float64
# data_date
# 2018-06-28    6107.6076
# Name: (bitcoin, 6107.6076), dtype: float64
# data_date
# 2018-06-27    6128.2277
# Name: (bitcoin, 6128.2277), dtype: float64
# data_date
# 2017-10-30    6131.3642
# Name: (bitcoin, 6131.3642), dtype: float64
# data_date
# 2018-06-23    6166.6832
# Name: (bitcoin, 6166.6832), dtype: float64
# data_date
# 2018-08-11    6207.1632
# Name: (bitcoin, 6207.1632), dtype: float64
# data_date
# 2018-06-25    6222.7026
# Name: (bitcoin, 6222.7026), dtype: float64
# data_date
# 2018-06-26    6225.0147
# Name: (bitcoin, 6225.0147), dtype: float64
# data_date
# 2018-07-14    6252.1209
# Name: (bitcoin, 6252.1209), dtype: float64
# data_date
# 2017-10-31    6252.9071
# Name: (bitcoin, 6252.9071), dtype: float64
# data_date
# 2018-10-12    6283.4789
# Name: (bitcoin, 6283.4789), dtype: float64
# data_date
# 2018-10-11    6284.2787
# Name: (bitcoin, 6284.2787), dtype: float64
# data_date
# 2018-10-30    6288.2936
# Name: (bitcoin, 6288.2936), dtype: float64
# data_date
# 2018-10-13    6290.9485
# Name: (bitcoin, 6290.9485), dtype: float64
# data_date
# 2018-07-13    6291.0147
# Name: (bitcoin, 6291.0147), dtype: float64
# data_date
# 2018-10-31    6293.3032
# Name: (bitcoin, 6293.3032), dtype: float64
# data_date
# 2018-09-12    6299.2714
# Name: (bitcoin, 6299.2714), dtype: float64
# data_date
# 2018-10-14    6304.6122
# Name: (bitcoin, 6304.6122), dtype: float64
# data_date
# 2018-09-18    6310.0102
# Name: (bitcoin, 6310.0102), dtype: float64
# data_date
# 2017-11-13    6311.6495
# Name: (bitcoin, 6311.6495), dtype: float64
# data_date
# 2018-09-10    6317.5845
# Name: (bitcoin, 6317.5845), dtype: float64
# data_date
# 2018-09-09    6319.8478
# Name: (bitcoin, 6319.8478), dtype: float64
# data_date
# 2018-11-13    6321.4822
# Name: (bitcoin, 6321.4822), dtype: float64
# data_date
# 2018-09-11    6323.9486
# Name: (bitcoin, 6323.9486), dtype: float64
# data_date
# 2018-11-01    6326.316
# Name: (bitcoin, 6326.316), dtype: float64
# data_date
# 2018-08-12    6334.0462
# Name: (bitcoin, 6334.0462), dtype: float64
# data_date
# 2018-07-15    6340.1869
# Name: (bitcoin, 6340.1869), dtype: float64
# data_date
# 2018-10-29    6348.5797
# Name: (bitcoin, 6348.5797), dtype: float64
# data_date
# 2018-08-16    6351.2625
# Name: (bitcoin, 6351.2625), dtype: float64
# data_date
# 2018-09-19    6353.3433
# Name: (bitcoin, 6353.3433), dtype: float64
# data_date
# 2018-11-03    6354.2995
# Name: (bitcoin, 6354.2995), dtype: float64
# data_date
# 2018-08-13    6360.1919
# Name: (bitcoin, 6360.1919), dtype: float64
# data_date
# 2018-11-11    6362.0272
# Name: (bitcoin, 6362.0272), dtype: float64
# data_date
# 2018-11-12    6367.3582
# Name: (bitcoin, 6367.3582), dtype: float64
# data_date
# 2018-08-15    6375.5075
# Name: (bitcoin, 6375.5075), dtype: float64
# data_date
# 2018-11-02    6376.5276
# Name: (bitcoin, 6376.5276), dtype: float64
# data_date
# 2018-11-10    6376.685
# Name: (bitcoin, 6376.685), dtype: float64
# data_date
# 2018-06-22    6379.0833
# Name: (bitcoin, 6379.0833), dtype: float64
# data_date
# 2018-07-01    6379.3998
# Name: (bitcoin, 6379.3998), dtype: float64
# data_date
# 2018-06-30    6379.9762
# Name: (bitcoin, 6379.9762), dtype: float64
# data_date
# 2018-11-04    6382.8929
# Name: (bitcoin, 6382.8929), dtype: float64
# data_date
# 2018-11-09    6388.8535
# Name: (bitcoin, 6388.8535), dtype: float64
# data_date
# 2018-08-09    6393.927
# Name: (bitcoin, 6393.927), dtype: float64
# data_date
# 2018-09-08    6399.1874
# Name: (bitcoin, 6399.1874), dtype: float64
# data_date
# 2018-08-10    6407.8729
# Name: (bitcoin, 6407.8729), dtype: float64
# data_date
# 2018-09-17    6414.0105
# Name: (bitcoin, 6414.0105), dtype: float64
# data_date
# 2018-08-21    6416.4232
# Name: (bitcoin, 6416.4232), dtype: float64
# data_date
# 2018-10-26    6416.5305
# Name: (bitcoin, 6416.5305), dtype: float64
# data_date
# 2018-11-05    6417.581
# Name: (bitcoin, 6417.581), dtype: float64
# data_date
# 2018-09-20    6418.3251
# Name: (bitcoin, 6418.3251), dtype: float64
# data_date
# 2018-10-25    6419.549
# Name: (bitcoin, 6419.549), dtype: float64
# data_date
# 2018-10-23    6421.3412
# Name: (bitcoin, 6421.3412), dtype: float64
# data_date
# 2018-11-06    6422.7625
# Name: (bitcoin, 6422.7625), dtype: float64
# data_date
# 2018-08-19    6423.5206
# Name: (bitcoin, 6423.5206), dtype: float64
# data_date
# 2018-10-28    6424.7343
# Name: (bitcoin, 6424.7343), dtype: float64
# data_date
# 2018-10-27    6426.6957
# Name: (bitcoin, 6426.6957), dtype: float64
# data_date
# 2018-10-19    6432.0774
# Name: (bitcoin, 6432.0774), dtype: float64
# data_date
# 2018-10-22    6432.9957
# Name: (bitcoin, 6432.9957), dtype: float64
# data_date
# 2018-09-25    6438.107
# Name: (bitcoin, 6438.107), dtype: float64
# data_date
# 2018-08-23    6438.8638
# Name: (bitcoin, 6438.8638), dtype: float64
# data_date
# 2018-08-08    6440.3697
# Name: (bitcoin, 6440.3697), dtype: float64
# data_date
# 2018-10-20    6441.8188
# Name: (bitcoin, 6441.8188), dtype: float64
# data_date
# 2018-10-24    6446.5533
# Name: (bitcoin, 6446.5533), dtype: float64
# data_date
# 2018-08-18    6448.5513
# Name: (bitcoin, 6448.5513), dtype: float64
# data_date
# 2018-09-13    6458.9547
# Name: (bitcoin, 6458.9547), dtype: float64
# data_date
# 2018-08-20    6462.0571
# Name: (bitcoin, 6462.0571), dtype: float64
# data_date
# 2018-07-02    6466.3136
# Name: (bitcoin, 6466.3136), dtype: float64
# data_date
# 2018-11-08    6466.9645
# Name: (bitcoin, 6466.9645), dtype: float64
# data_date
# 2018-09-07    6473.9549
# Name: (bitcoin, 6473.9549), dtype: float64
# data_date
# 2018-09-06    6478.9959
# Name: (bitcoin, 6478.9959), dtype: float64
# data_date
# 2018-08-17    6480.0611
# Name: (bitcoin, 6480.0611), dtype: float64
# data_date
# 2018-10-03    6481.0843
# Name: (bitcoin, 6481.0843), dtype: float64
# data_date
# 2018-10-21    6482.1658
# Name: (bitcoin, 6482.1658), dtype: float64
# data_date
# 2018-10-18    6483.8042
# Name: (bitcoin, 6483.8042), dtype: float64
# data_date
# 2018-09-26    6485.489
# Name: (bitcoin, 6485.489), dtype: float64
# data_date
# 2018-07-12    6489.0484
# Name: (bitcoin, 6489.0484), dtype: float64
# data_date
# 2018-06-16    6493.5219
# Name: (bitcoin, 6493.5219), dtype: float64
# data_date
# 2018-10-15    6494.4976
# Name: (bitcoin, 6494.4976), dtype: float64
# data_date
# 2018-09-16    6495.4002
# Name: (bitcoin, 6495.4002), dtype: float64
# data_date
# 2018-10-17    6502.7161
# Name: (bitcoin, 6502.7161), dtype: float64
# data_date
# 2018-06-14    6505.4762
# Name: (bitcoin, 6505.4762), dtype: float64
# data_date
# 2017-11-01    6508.7579
# Name: (bitcoin, 6508.7579), dtype: float64
# data_date
# 2018-09-14    6513.0281
# Name: (bitcoin, 6513.0281), dtype: float64
# data_date
# 2018-11-07    6515.7451
# Name: (bitcoin, 6515.7451), dtype: float64
# data_date
# 2018-10-16    6522.8372
# Name: (bitcoin, 6522.8372), dtype: float64
# data_date
# 2017-11-11    6524.6881
# Name: (bitcoin, 6524.6881), dtype: float64
# data_date
# 2018-07-10    6525.5094
# Name: (bitcoin, 6525.5094), dtype: float64
# data_date
# 2018-09-15    6528.6224
# Name: (bitcoin, 6528.6224), dtype: float64
# data_date
# 2018-07-16    6530.5737
# Name: (bitcoin, 6530.5737), dtype: float64
# data_date
# 2018-06-18    6540.4034
# Name: (bitcoin, 6540.4034), dtype: float64
# data_date
# 2018-09-27    6541.0338
# Name: (bitcoin, 6541.0338), dtype: float64
# data_date
# 2018-06-17    6543.9392
# Name: (bitcoin, 6543.9392), dtype: float64
# data_date
# 2018-07-06    6549.1112
# Name: (bitcoin, 6549.1112), dtype: float64
# data_date
# 2018-08-24    6555.7032
# Name: (bitcoin, 6555.7032), dtype: float64
# data_date
# 2018-10-10    6562.6941
# Name: (bitcoin, 6562.6941), dtype: float64
# data_date
# 2017-11-14    6563.2021
# Name: (bitcoin, 6563.2021), dtype: float64
# data_date
# 2018-09-29    6565.7065
# Name: (bitcoin, 6565.7065), dtype: float64
# data_date
# 2018-10-04    6567.2087
# Name: (bitcoin, 6567.2087), dtype: float64
# data_date
# 2018-06-15    6568.1506
# Name: (bitcoin, 6568.1506), dtype: float64
# data_date
# 2018-10-02    6569.1736
# Name: (bitcoin, 6569.1736), dtype: float64
# data_date
# 2018-10-05    6571.5219
# Name: (bitcoin, 6571.5219), dtype: float64
# data_date
# 2018-10-07    6576.3334
# Name: (bitcoin, 6576.3334), dtype: float64
# data_date
# 2018-07-04    6581.0093
# Name: (bitcoin, 6581.0093), dtype: float64
# data_date
# 2018-08-22    6584.1557
# Name: (bitcoin, 6584.1557), dtype: float64
# data_date
# 2018-10-06    6584.6514
# Name: (bitcoin, 6584.6514), dtype: float64
# data_date
# 2018-07-11    6585.4815
# Name: (bitcoin, 6585.4815), dtype: float64
# data_date
# 2018-10-01    6599.8416
# Name: (bitcoin, 6599.8416), dtype: float64
# data_date
# 2018-07-03    6601.0725
# Name: (bitcoin, 6601.0725), dtype: float64
# data_date
# 2018-09-30    6603.8329
# Name: (bitcoin, 6603.8329), dtype: float64
# data_date
# 2018-10-08    6622.02
# Name: (bitcoin, 6622.02), dtype: float64
# data_date
# 2018-07-05    6629.1363
# Name: (bitcoin, 6629.1363), dtype: float64
# data_date
# 2018-10-09    6632.0089
# Name: (bitcoin, 6632.0089), dtype: float64
# data_date
# 2018-09-24    6646.4958
# Name: (bitcoin, 6646.4958), dtype: float64
# data_date
# 2018-07-07    6655.9109
# Name: (bitcoin, 6655.9109), dtype: float64
# data_date
# 2018-09-21    6660.0805
# Name: (bitcoin, 6660.0805), dtype: float64
# data_date
# 2018-04-06    6667.745
# Name: (bitcoin, 6667.745), dtype: float64
# data_date
# 2018-09-28    6676.7634
# Name: (bitcoin, 6676.7634), dtype: float64
# data_date
# 2018-08-26    6691.8868
# Name: (bitcoin, 6691.8868), dtype: float64
# data_date
# 2018-06-20    6694.0527
# Name: (bitcoin, 6694.0527), dtype: float64
# data_date
# 2018-09-22    6707.2502
# Name: (bitcoin, 6707.2502), dtype: float64
# data_date
# 2018-09-23    6714.8067
# Name: (bitcoin, 6714.8067), dtype: float64
# data_date
# 2018-08-27    6717.0788
# Name: (bitcoin, 6717.0788), dtype: float64
# data_date
# 2018-08-25    6730.7092
# Name: (bitcoin, 6730.7092), dtype: float64
# data_date
# 2018-06-19    6732.8205
# Name: (bitcoin, 6732.8205), dtype: float64
# data_date
# 2018-07-09    6741.7765
# Name: (bitcoin, 6741.7765), dtype: float64
# data_date
# 2018-06-21    6742.6611
# Name: (bitcoin, 6742.6611), dtype: float64
# data_date
# 2018-04-05    6775.8313
# Name: (bitcoin, 6775.8313), dtype: float64
# data_date
# 2018-06-11    6781.8219
# Name: (bitcoin, 6781.8219), dtype: float64
# data_date
# 2018-06-12    6788.0829
# Name: (bitcoin, 6788.0829), dtype: float64
# data_date
# 2018-04-10    6797.6746
# Name: (bitcoin, 6797.6746), dtype: float64
# data_date
# 2018-07-08    6818.2082
# Name: (bitcoin, 6818.2082), dtype: float64
# data_date
# 2018-04-01    6821.6184
# Name: (bitcoin, 6821.6184), dtype: float64
# data_date
# 2018-02-06    6832.4936
# Name: (bitcoin, 6832.4936), dtype: float64
# data_date
# 2018-07-17    6884.5482
# Name: (bitcoin, 6884.5482), dtype: float64
# data_date
# 2018-03-30    6898.483
# Name: (bitcoin, 6898.483), dtype: float64
# data_date
# 2018-04-07    6909.6372
# Name: (bitcoin, 6909.6372), dtype: float64
# data_date
# 2018-04-11    6913.9478
# Name: (bitcoin, 6913.9478), dtype: float64
# data_date
# 2018-04-09    6916.0762
# Name: (bitcoin, 6916.0762), dtype: float64
# data_date
# 2018-08-30    6938.1899
# Name: (bitcoin, 6938.1899), dtype: float64
# data_date
# 2017-11-10    6943.8492
# Name: (bitcoin, 6943.8492), dtype: float64
# data_date
# 2017-11-02    6962.236
# Name: (bitcoin, 6962.236), dtype: float64
# data_date
# 2018-08-28    6975.3463
# Name: (bitcoin, 6975.3463), dtype: float64
# data_date
# 2018-08-07    6982.2152
# Name: (bitcoin, 6982.2152), dtype: float64
# data_date
# 2018-08-31    6986.5
# Name: (bitcoin, 6986.5), dtype: float64
# data_date
# 2018-08-05    6987.2119
# Name: (bitcoin, 6987.2119), dtype: float64
# data_date
# 2018-08-06    6989.5894
# Name: (bitcoin, 6989.5894), dtype: float64
# data_date
# 2018-04-02    6998.5127
# Name: (bitcoin, 6998.5127), dtype: float64
# data_date
# 2018-04-08    7017.6617
# Name: (bitcoin, 7017.6617), dtype: float64
# data_date
# 2018-03-31    7022.3925
# Name: (bitcoin, 7022.3925), dtype: float64
# data_date
# 2017-11-15    7024.9451
# Name: (bitcoin, 7024.9451), dtype: float64
# data_date
# 2018-08-29    7045.3338
# Name: (bitcoin, 7045.3338), dtype: float64
# data_date
# 2018-04-04    7100.8827
# Name: (bitcoin, 7100.8827), dtype: float64
# data_date
# 2017-11-07    7105.9659
# Name: (bitcoin, 7105.9659), dtype: float64
# data_date
# 2018-09-01    7107.016
# Name: (bitcoin, 7107.016), dtype: float64
# data_date
# 2018-09-05    7141.0566
# Name: (bitcoin, 7141.0566), dtype: float64
# data_date
# 2018-06-10    7192.4504
# Name: (bitcoin, 7192.4504), dtype: float64
# data_date
# 2017-11-06    7233.595
# Name: (bitcoin, 7233.595), dtype: float64
# data_date
# 2017-11-09    7236.2841
# Name: (bitcoin, 7236.2841), dtype: float64
# data_date
# 2017-11-03    7236.6314
# Name: (bitcoin, 7236.6314), dtype: float64
# data_date
# 2018-09-02    7236.9423
# Name: (bitcoin, 7236.9423), dtype: float64
# data_date
# 2018-08-04    7247.2623
# Name: (bitcoin, 7247.2623), dtype: float64
# data_date
# 2018-09-03    7252.201
# Name: (bitcoin, 7252.201), dtype: float64
# data_date
# 2017-11-04    7256.2289
# Name: (bitcoin, 7256.2289), dtype: float64
# data_date
# 2018-05-28    7317.6978
# Name: (bitcoin, 7317.6978), dtype: float64
# data_date
# 2018-09-04    7318.5833
# Name: (bitcoin, 7318.5833), dtype: float64
# data_date
# 2018-05-29    7327.5205
# Name: (bitcoin, 7327.5205), dtype: float64
# data_date
# 2018-04-03    7342.9677
# Name: (bitcoin, 7342.9677), dtype: float64
# data_date
# 2018-07-21    7346.6049
# Name: (bitcoin, 7346.6049), dtype: float64
# data_date
# 2018-04-12    7349.325
# Name: (bitcoin, 7349.325), dtype: float64
# data_date
# 2018-05-27    7366.5779
# Name: (bitcoin, 7366.5779), dtype: float64
# data_date
# 2017-11-08    7379.4679
# Name: (bitcoin, 7379.4679), dtype: float64
# data_date
# 2018-08-03    7389.6891
# Name: (bitcoin, 7389.6891), dtype: float64
# data_date
# 2018-07-19    7395.3702
# Name: (bitcoin, 7395.3702), dtype: float64
# data_date
# 2018-07-18    7409.998
# Name: (bitcoin, 7409.998), dtype: float64
# data_date
# 2018-07-20    7425.9746
# Name: (bitcoin, 7425.9746), dtype: float64
# data_date
# 2018-07-22    7446.3684
# Name: (bitcoin, 7446.3684), dtype: float64
# data_date
# 2018-05-30    7449.7914
# Name: (bitcoin, 7449.7914), dtype: float64
# data_date
# 2017-11-16    7453.8879
# Name: (bitcoin, 7453.8879), dtype: float64
# data_date
# 2017-11-05    7469.965
# Name: (bitcoin, 7469.965), dtype: float64
# data_date
# 2018-06-01    7491.1484
# Name: (bitcoin, 7491.1484), dtype: float64
# data_date
# 2018-06-05    7491.3015
# Name: (bitcoin, 7491.3015), dtype: float64
# data_date
# 2018-05-31    7502.6476
# Name: (bitcoin, 7502.6476), dtype: float64
# data_date
# 2018-05-25    7525.9543
# Name: (bitcoin, 7525.9543), dtype: float64
# data_date
# 2018-03-29    7530.9995
# Name: (bitcoin, 7530.9995), dtype: float64
# data_date
# 2018-05-26    7531.1852
# Name: (bitcoin, 7531.1852), dtype: float64
# data_date
# 2018-08-01    7564.2783
# Name: (bitcoin, 7564.2783), dtype: float64
# data_date
# 2018-06-06    7572.9151
# Name: (bitcoin, 7572.9151), dtype: float64
# data_date
# 2018-06-02    7575.9304
# Name: (bitcoin, 7575.9304), dtype: float64
# data_date
# 2018-08-02    7581.6106
# Name: (bitcoin, 7581.6106), dtype: float64
# data_date
# 2018-06-04    7582.7935
# Name: (bitcoin, 7582.7935), dtype: float64
# data_date
# 2018-05-24    7583.1107
# Name: (bitcoin, 7583.1107), dtype: float64
# data_date
# 2018-06-08    7610.1023
# Name: (bitcoin, 7610.1023), dtype: float64
# data_date
# 2018-06-03    7639.7031
# Name: (bitcoin, 7639.7031), dtype: float64
# data_date
# 2018-02-05    7646.5559
# Name: (bitcoin, 7646.5559), dtype: float64
# data_date
# 2018-06-09    7658.5374
# Name: (bitcoin, 7658.5374), dtype: float64
# data_date
# 2018-07-23    7672.2795
# Name: (bitcoin, 7672.2795), dtype: float64
# data_date
# 2018-03-18    7675.353
# Name: (bitcoin, 7675.353), dtype: float64
# data_date
# 2018-06-07    7675.7741
# Name: (bitcoin, 7675.7741), dtype: float64
# data_date
# 2017-11-18    7693.8791
# Name: (bitcoin, 7693.8791), dtype: float64
# data_date
# 2017-11-17    7831.5033
# Name: (bitcoin, 7831.5033), dtype: float64
# data_date
# 2017-11-19    7833.1737
# Name: (bitcoin, 7833.1737), dtype: float64
# data_date
# 2018-05-23    7839.0237
# Name: (bitcoin, 7839.0237), dtype: float64
# data_date
# 2018-02-07    7899.5663
# Name: (bitcoin, 7899.5663), dtype: float64
# data_date
# 2018-07-31    7907.5243
# Name: (bitcoin, 7907.5243), dtype: float64
# data_date
# 2018-03-28    7935.0471
# Name: (bitcoin, 7935.0471), dtype: float64
# data_date
# 2018-03-27    7978.072
# Name: (bitcoin, 7978.072), dtype: float64
# data_date
# 2018-07-27    8004.3081
# Name: (bitcoin, 8004.3081), dtype: float64
# data_date
# 2018-04-13    8007.8258
# Name: (bitcoin, 8007.8258), dtype: float64
# data_date
# 2018-04-14    8024.7012
# Name: (bitcoin, 8024.7012), dtype: float64
# data_date
# 2018-07-24    8058.3217
# Name: (bitcoin, 8058.3217), dtype: float64
# data_date
# 2018-04-17    8072.6897
# Name: (bitcoin, 8072.6897), dtype: float64
# data_date
# 2018-03-17    8081.7781
# Name: (bitcoin, 8081.7781), dtype: float64
# data_date
# 2018-04-18    8084.9797
# Name: (bitcoin, 8084.9797), dtype: float64
# data_date
# 2018-04-16    8102.3828
# Name: (bitcoin, 8102.3828), dtype: float64
# data_date
# 2018-03-15    8109.7639
# Name: (bitcoin, 8109.7639), dtype: float64
# data_date
# 2018-05-18    8114.1721
# Name: (bitcoin, 8114.1721), dtype: float64
# data_date
# 2017-11-20    8119.8048
# Name: (bitcoin, 8119.8048), dtype: float64
# data_date
# 2018-07-30    8121.8085
# Name: (bitcoin, 8121.8085), dtype: float64
# data_date
# 2018-07-28    8158.6671
# Name: (bitcoin, 8158.6671), dtype: float64
# data_date
# 2017-11-24    8170.7565
# Name: (bitcoin, 8170.7565), dtype: float64
# data_date
# 2018-07-26    8171.3691
# Name: (bitcoin, 8171.3691), dtype: float64
# data_date
# 2017-11-21    8175.8076
# Name: (bitcoin, 8175.8076), dtype: float64
# data_date
# 2017-11-23    8180.0303
# Name: (bitcoin, 8180.0303), dtype: float64
# data_date
# 2018-07-29    8183.3394
# Name: (bitcoin, 8183.3394), dtype: float64
# data_date
# 2017-11-22    8201.6431
# Name: (bitcoin, 8201.6431), dtype: float64
# data_date
# 2018-02-11    8210.8112
# Name: (bitcoin, 8210.8112), dtype: float64
# data_date
# 2018-03-26    8222.1146
# Name: (bitcoin, 8222.1146), dtype: float64
# data_date
# 2018-02-08    8228.8196
# Name: (bitcoin, 8228.8196), dtype: float64
# data_date
# 2018-07-25    8232.6845
# Name: (bitcoin, 8232.6845), dtype: float64
# data_date
# 2018-04-19    8242.6121
# Name: (bitcoin, 8242.6121), dtype: float64
# data_date
# 2018-04-15    8247.0674
# Name: (bitcoin, 8247.0674), dtype: float64
# data_date
# 2018-05-22    8266.0665
# Name: (bitcoin, 8266.0665), dtype: float64
# data_date
# 2018-02-09    8271.7872
# Name: (bitcoin, 8271.7872), dtype: float64
# data_date
# 2018-05-19    8277.994
# Name: (bitcoin, 8277.994), dtype: float64
# data_date
# 2018-05-16    8295.4024
# Name: (bitcoin, 8295.4024), dtype: float64
# data_date
# 2018-05-17    8297.2588
# Name: (bitcoin, 8297.2588), dtype: float64
# data_date
# 2018-03-16    8317.4618
# Name: (bitcoin, 8317.4618), dtype: float64
# data_date
# 2018-03-19    8350.2081
# Name: (bitcoin, 8350.2081), dtype: float64
# data_date
# 2018-05-20    8387.2509
# Name: (bitcoin, 8387.2509), dtype: float64
# data_date
# 2018-05-12    8449.5836
# Name: (bitcoin, 8449.5836), dtype: float64
# data_date
# 2018-04-20    8472.0475
# Name: (bitcoin, 8472.0475), dtype: float64
# data_date
# 2018-05-21    8473.4111
# Name: (bitcoin, 8473.4111), dtype: float64
# data_date
# 2017-11-25    8476.4422
# Name: (bitcoin, 8476.4422), dtype: float64
# data_date
# 2018-03-23    8538.6037
# Name: (bitcoin, 8538.6037), dtype: float64
# data_date
# 2018-03-25    8548.6952
# Name: (bitcoin, 8548.6952), dtype: float64
# data_date
# 2018-05-13    8587.8977
# Name: (bitcoin, 8587.8977), dtype: float64
# data_date
# 2018-05-14    8596.4033
# Name: (bitcoin, 8596.4033), dtype: float64
# data_date
# 2018-02-13    8623.1956
# Name: (bitcoin, 8623.1956), dtype: float64
# data_date
# 2018-03-20    8623.2054
# Name: (bitcoin, 8623.2054), dtype: float64
# data_date
# 2018-02-02    8631.4466
# Name: (bitcoin, 8631.4466), dtype: float64
# data_date
# 2018-02-12    8637.552
# Name: (bitcoin, 8637.552), dtype: float64
# data_date
# 2018-02-10    8652.1339
# Name: (bitcoin, 8652.1339), dtype: float64
# data_date
# 2018-05-15    8659.7011
# Name: (bitcoin, 8659.7011), dtype: float64
# data_date
# 2018-05-11    8722.4448
# Name: (bitcoin, 8722.4448), dtype: float64
# data_date
# 2018-02-04    8762.662
# Name: (bitcoin, 8762.662), dtype: float64
# data_date
# 2018-03-14    8770.1794
# Name: (bitcoin, 8770.1794), dtype: float64
# data_date
# 2018-03-22    8792.8392
# Name: (bitcoin, 8792.8392), dtype: float64
# data_date
# 2018-04-21    8819.894
# Name: (bitcoin, 8819.894), dtype: float64
# data_date
# 2018-03-24    8863.3203
# Name: (bitcoin, 8863.3203), dtype: float64
# data_date
# 2018-03-09    8902.8578
# Name: (bitcoin, 8902.8578), dtype: float64
# data_date
# 2018-04-22    8914.1631
# Name: (bitcoin, 8914.1631), dtype: float64
# data_date
# 2018-04-23    8919.2977
# Name: (bitcoin, 8919.2977), dtype: float64
# data_date
# 2018-02-03    8949.4095
# Name: (bitcoin, 8949.4095), dtype: float64
# data_date
# 2018-03-21    8990.2473
# Name: (bitcoin, 8990.2473), dtype: float64
# data_date
# 2018-05-01    9020.0315
# Name: (bitcoin, 9020.0315), dtype: float64
# data_date
# 2018-02-14    9025.8784
# Name: (bitcoin, 9025.8784), dtype: float64
# data_date
# 2018-03-11    9059.0849
# Name: (bitcoin, 9059.0849), dtype: float64
# data_date
# 2017-11-26    9067.2775
# Name: (bitcoin, 9067.2775), dtype: float64
# data_date
# 2018-05-02    9130.8574
# Name: (bitcoin, 9130.8574), dtype: float64
# data_date
# 2018-04-27    9160.5502
# Name: (bitcoin, 9160.5502), dtype: float64
# data_date
# 2018-03-13    9162.9406
# Name: (bitcoin, 9162.9406), dtype: float64
# data_date
# 2018-05-09    9206.1511
# Name: (bitcoin, 9206.1511), dtype: float64
# data_date
# 2018-03-10    9242.5349
# Name: (bitcoin, 9242.5349), dtype: float64
# data_date
# 2018-05-08    9262.515
# Name: (bitcoin, 9262.515), dtype: float64
# data_date
# 2018-04-28    9263.9
# Name: (bitcoin, 9263.9), dtype: float64
# data_date
# 2018-05-10    9277.0094
# Name: (bitcoin, 9277.0094), dtype: float64
# data_date
# 2018-04-30    9309.7666
# Name: (bitcoin, 9309.7666), dtype: float64
# data_date
# 2018-05-07    9312.4895
# Name: (bitcoin, 9312.4895), dtype: float64
# ...
# data_date
# 2018-07-06    0.4725
# Name: (ripple, 0.4725), dtype: float64
# data_date
# 2018-10-07    0.4759
# Name: (ripple, 0.4759), dtype: float64
# data_date
# 2018-06-26    0.4768
# Name: (ripple, 0.4768), dtype: float64
# data_date
# 2018-07-07    0.4769
# 2018-11-17    0.4769
# Name: (ripple, 0.4769), dtype: float64
# data_date
# 2018-07-09    0.4803
# Name: (ripple, 0.4803), dtype: float64
# data_date
# 2018-10-09    0.4807
# Name: (ripple, 0.4807), dtype: float64
# data_date
# 2018-06-25    0.4811
# Name: (ripple, 0.4811), dtype: float64
# data_date
# 2018-07-19    0.4821
# Name: (ripple, 0.4821), dtype: float64
# data_date
# 2018-04-01    0.485
# Name: (ripple, 0.485), dtype: float64
# data_date
# 2018-11-14    0.4851
# Name: (ripple, 0.4851), dtype: float64
# data_date
# 2018-04-10    0.4853
# Name: (ripple, 0.4853), dtype: float64
# data_date
# 2018-07-17    0.4854
# Name: (ripple, 0.4854), dtype: float64
# data_date
# 2018-04-05    0.4859
# Name: (ripple, 0.4859), dtype: float64
# data_date
# 2018-04-02    0.4861
# Name: (ripple, 0.4861), dtype: float64
# data_date
# 2018-04-07    0.4866
# Name: (ripple, 0.4866), dtype: float64
# data_date
# 2018-11-19    0.4867
# Name: (ripple, 0.4867), dtype: float64
# data_date
# 2018-07-05    0.488
# Name: (ripple, 0.488), dtype: float64
# data_date
# 2018-10-08    0.4884
# Name: (ripple, 0.4884), dtype: float64
# data_date
# 2018-07-04    0.489
# Name: (ripple, 0.489), dtype: float64
# data_date
# 2018-06-23    0.4896
# Name: (ripple, 0.4896), dtype: float64
# data_date
# 2018-07-08    0.4909
# Name: (ripple, 0.4909), dtype: float64
# data_date
# 2018-04-09    0.4913
# Name: (ripple, 0.4913), dtype: float64
# data_date
# 2018-04-08    0.4915
# Name: (ripple, 0.4915), dtype: float64
# data_date
# 2018-03-30    0.495
# Name: (ripple, 0.495), dtype: float64
# data_date
# 2018-04-11    0.4963
# Name: (ripple, 0.4963), dtype: float64
# data_date
# 2018-07-03    0.4968
# Name: (ripple, 0.4968), dtype: float64
# data_date
# 2018-10-06    0.5012
# Name: (ripple, 0.5012), dtype: float64
# data_date
# 2018-11-09    0.5015
# Name: (ripple, 0.5015), dtype: float64
# data_date
# 2018-11-11    0.5017
# Name: (ripple, 0.5017), dtype: float64
# data_date
# 2018-11-10    0.5042
# Name: (ripple, 0.5042), dtype: float64
# data_date
# 2018-11-18    0.5072
# Name: (ripple, 0.5072), dtype: float64
# data_date
# 2018-03-31    0.5073
# Name: (ripple, 0.5073), dtype: float64
# data_date
# 2018-07-18    0.5082
# Name: (ripple, 0.5082), dtype: float64
# data_date
# 2018-06-22    0.5088
# Name: (ripple, 0.5088), dtype: float64
# data_date
# 2018-11-12    0.509
# Name: (ripple, 0.509), dtype: float64
# data_date
# 2018-04-04    0.5109
# Name: (ripple, 0.5109), dtype: float64
# data_date
# 2018-11-08    0.5112
# Name: (ripple, 0.5112), dtype: float64
# data_date
# 2018-11-13    0.5138
# Name: (ripple, 0.5138), dtype: float64
# data_date
# 2018-10-05    0.5184
# Name: (ripple, 0.5184), dtype: float64
# data_date
# 2018-09-21    0.5194
# Name: (ripple, 0.5194), dtype: float64
# data_date
# 2018-04-03    0.5207
# Name: (ripple, 0.5207), dtype: float64
# data_date
# 2018-10-03    0.5226
# Name: (ripple, 0.5226), dtype: float64
# data_date
# 2018-11-06    0.5264
# Name: (ripple, 0.5264), dtype: float64
# data_date
# 2018-06-18    0.5266
# Name: (ripple, 0.5266), dtype: float64
# data_date
# 2018-09-26    0.5273
# Name: (ripple, 0.5273), dtype: float64
# data_date
# 2018-09-27    0.5292
# Name: (ripple, 0.5292), dtype: float64
# data_date
# 2018-11-07    0.5327
# Name: (ripple, 0.5327), dtype: float64
# data_date
# 2018-06-16    0.5342
# Name: (ripple, 0.5342), dtype: float64
# data_date
# 2018-06-17    0.5343
# 2018-10-04    0.5343
# Name: (ripple, 0.5343), dtype: float64
# data_date
# 2018-06-20    0.5353
# 2018-09-28    0.5353
# Name: (ripple, 0.5353), dtype: float64
# data_date
# 2018-06-21    0.5386
# Name: (ripple, 0.5386), dtype: float64
# data_date
# 2018-09-24    0.5389
# Name: (ripple, 0.5389), dtype: float64
# data_date
# 2018-03-29    0.5396
# Name: (ripple, 0.5396), dtype: float64
# data_date
# 2018-06-13    0.5413
# Name: (ripple, 0.5413), dtype: float64
# data_date
# 2018-06-19    0.5442
# Name: (ripple, 0.5442), dtype: float64
# data_date
# 2018-06-14    0.548
# Name: (ripple, 0.548), dtype: float64
# data_date
# 2018-06-15    0.5482
# Name: (ripple, 0.5482), dtype: float64
# data_date
# 2018-09-29    0.5528
# Name: (ripple, 0.5528), dtype: float64
# data_date
# 2018-04-12    0.5556
# Name: (ripple, 0.5556), dtype: float64
# data_date
# 2018-10-02    0.5573
# Name: (ripple, 0.5573), dtype: float64
# data_date
# 2018-09-22    0.5606
# Name: (ripple, 0.5606), dtype: float64
# data_date
# 2018-09-23    0.5736
# Name: (ripple, 0.5736), dtype: float64
# data_date
# 2018-10-01    0.5742
# Name: (ripple, 0.5742), dtype: float64
# data_date
# 2018-03-28    0.5755
# Name: (ripple, 0.5755), dtype: float64
# data_date
# 2018-03-27    0.5791
# Name: (ripple, 0.5791), dtype: float64
# data_date
# 2018-06-11    0.5827
# Name: (ripple, 0.5827), dtype: float64
# data_date
# 2018-06-12    0.5829
# Name: (ripple, 0.5829), dtype: float64
# data_date
# 2018-05-29    0.5833
# Name: (ripple, 0.5833), dtype: float64
# data_date
# 2018-09-30    0.5847
# Name: (ripple, 0.5847), dtype: float64
# data_date
# 2018-05-28    0.5873
# Name: (ripple, 0.5873), dtype: float64
# data_date
# 2018-03-18    0.5939
# Name: (ripple, 0.5939), dtype: float64
# data_date
# 2018-03-26    0.6058
# Name: (ripple, 0.6058), dtype: float64
# data_date
# 2018-05-30    0.6099
# Name: (ripple, 0.6099), dtype: float64
# data_date
# 2018-05-27    0.6102
# Name: (ripple, 0.6102), dtype: float64
# data_date
# 2018-05-31    0.6138
# Name: (ripple, 0.6138), dtype: float64
# data_date
# 2018-06-01    0.6164
# Name: (ripple, 0.6164), dtype: float64
# data_date
# 2018-05-25    0.6187
# Name: (ripple, 0.6187), dtype: float64
# data_date
# 2018-05-24    0.619
# Name: (ripple, 0.619), dtype: float64
# data_date
# 2018-05-26    0.6191
# Name: (ripple, 0.6191), dtype: float64
# data_date
# 2018-06-10    0.6215
# Name: (ripple, 0.6215), dtype: float64
# data_date
# 2018-05-23    0.6239
# Name: (ripple, 0.6239), dtype: float64
# data_date
# 2018-03-23    0.6288
# Name: (ripple, 0.6288), dtype: float64
# data_date
# 2017-12-14    0.6304
# Name: (ripple, 0.6304), dtype: float64
# data_date
# 2018-03-25    0.6341
# Name: (ripple, 0.6341), dtype: float64
# data_date
# 2018-06-02    0.639
# Name: (ripple, 0.639), dtype: float64
# data_date
# 2018-04-14    0.644
# Name: (ripple, 0.644), dtype: float64
# data_date
# 2018-03-24    0.6489
# Name: (ripple, 0.6489), dtype: float64
# data_date
# 2018-04-13    0.6536
# Name: (ripple, 0.6536), dtype: float64
# data_date
# 2018-03-17    0.6574
# Name: (ripple, 0.6574), dtype: float64
# data_date
# 2018-06-03    0.6587
# Name: (ripple, 0.6587), dtype: float64
# data_date
# 2018-03-22    0.66
# Name: (ripple, 0.66), dtype: float64
# data_date
# 2018-04-16    0.6603
# Name: (ripple, 0.6603), dtype: float64
# data_date
# 2018-06-05    0.6642
# Name: (ripple, 0.6642), dtype: float64
# data_date
# 2018-03-19    0.6647
# Name: (ripple, 0.6647), dtype: float64
# data_date
# 2018-04-17    0.6666
# Name: (ripple, 0.6666), dtype: float64
# data_date
# 2018-06-04    0.6693
# Name: (ripple, 0.6693), dtype: float64
# data_date
# 2018-04-15    0.6697
# Name: (ripple, 0.6697), dtype: float64
# data_date
# 2018-06-06    0.6706
# Name: (ripple, 0.6706), dtype: float64
# data_date
# 2018-06-08    0.6708
# Name: (ripple, 0.6708), dtype: float64
# data_date
# 2018-05-18    0.6714
# Name: (ripple, 0.6714), dtype: float64
# data_date
# 2018-05-22    0.6715
# Name: (ripple, 0.6715), dtype: float64
# data_date
# 2018-03-15    0.672
# Name: (ripple, 0.672), dtype: float64
# data_date
# 2018-02-06    0.6731
# Name: (ripple, 0.6731), dtype: float64
# data_date
# 2018-06-09    0.6736
# Name: (ripple, 0.6736), dtype: float64
# data_date
# 2018-05-19    0.6781
# Name: (ripple, 0.6781), dtype: float64
# data_date
# 2018-06-07    0.6801
# Name: (ripple, 0.6801), dtype: float64
# data_date
# 2018-04-18    0.6827
# Name: (ripple, 0.6827), dtype: float64
# data_date
# 2018-05-12    0.6878
# Name: (ripple, 0.6878), dtype: float64
# data_date
# 2018-03-16    0.6891
# Name: (ripple, 0.6891), dtype: float64
# data_date
# 2018-05-20    0.6897
# Name: (ripple, 0.6897), dtype: float64
# data_date
# 2018-03-20    0.6902
# Name: (ripple, 0.6902), dtype: float64
# data_date
# 2018-05-21    0.6906
# Name: (ripple, 0.6906), dtype: float64
# data_date
# 2018-05-16    0.6908
# Name: (ripple, 0.6908), dtype: float64
# data_date
# 2018-03-21    0.6909
# Name: (ripple, 0.6909), dtype: float64
# data_date
# 2018-05-17    0.6953
# Name: (ripple, 0.6953), dtype: float64
# data_date
# 2018-05-11    0.7123
# Name: (ripple, 0.7123), dtype: float64
# data_date
# 2017-12-20    0.7145
# Name: (ripple, 0.7145), dtype: float64
# data_date
# 2018-05-13    0.7161
# Name: (ripple, 0.7161), dtype: float64
# data_date
# 2017-12-18    0.7224
# Name: (ripple, 0.7224), dtype: float64
# data_date
# 2018-04-19    0.7296
# Name: (ripple, 0.7296), dtype: float64
# data_date
# 2017-12-17    0.7321
# Name: (ripple, 0.7321), dtype: float64
# data_date
# 2018-05-15    0.7322
# Name: (ripple, 0.7322), dtype: float64
# data_date
# 2018-05-14    0.7354
# Name: (ripple, 0.7354), dtype: float64
# data_date
# 2018-03-14    0.743
# Name: (ripple, 0.743), dtype: float64
# data_date
# 2018-02-08    0.7525
# Name: (ripple, 0.7525), dtype: float64
# data_date
# 2018-02-05    0.7527
# Name: (ripple, 0.7527), dtype: float64
# data_date
# 2017-12-16    0.7541
# Name: (ripple, 0.7541), dtype: float64
# data_date
# 2017-12-15    0.7546
# Name: (ripple, 0.7546), dtype: float64
# data_date
# 2018-02-07    0.757
# Name: (ripple, 0.757), dtype: float64
# data_date
# 2017-12-19    0.7734
# Name: (ripple, 0.7734), dtype: float64
# data_date
# 2018-03-13    0.7776
# Name: (ripple, 0.7776), dtype: float64
# data_date
# 2018-03-09    0.7852
# Name: (ripple, 0.7852), dtype: float64
# data_date
# 2018-03-11    0.7946
# Name: (ripple, 0.7946), dtype: float64
# data_date
# 2018-05-09    0.7982
# Name: (ripple, 0.7982), dtype: float64
# data_date
# 2018-05-10    0.7993
# Name: (ripple, 0.7993), dtype: float64
# data_date
# 2018-03-12    0.8017
# Name: (ripple, 0.8017), dtype: float64
# data_date
# 2018-03-10    0.8125
# Name: (ripple, 0.8125), dtype: float64
# data_date
# 2018-02-09    0.8229
# Name: (ripple, 0.8229), dtype: float64
# data_date
# 2018-05-01    0.8247
# Name: (ripple, 0.8247), dtype: float64
# data_date
# 2018-05-08    0.8256
# Name: (ripple, 0.8256), dtype: float64
# data_date
# 2018-05-07    0.8318
# Name: (ripple, 0.8318), dtype: float64
# data_date
# 2018-04-27    0.8363
# Name: (ripple, 0.8363), dtype: float64
# data_date
# 2018-03-08    0.8408
# Name: (ripple, 0.8408), dtype: float64
# data_date
# 2018-02-02    0.8459
# Name: (ripple, 0.8459), dtype: float64
# data_date
# 2018-04-25    0.8478
# Name: (ripple, 0.8478), dtype: float64
# data_date
# 2018-05-02    0.8503
# Name: (ripple, 0.8503), dtype: float64
# data_date
# 2018-04-30    0.851
# Name: (ripple, 0.851), dtype: float64
# data_date
# 2018-04-28    0.8511
# Name: (ripple, 0.8511), dtype: float64
# data_date
# 2018-04-20    0.861
# Name: (ripple, 0.861), dtype: float64
# data_date
# 2018-04-23    0.8682
# Name: (ripple, 0.8682), dtype: float64
# data_date
# 2018-05-03    0.8686
# Name: (ripple, 0.8686), dtype: float64
# data_date
# 2018-04-21    0.87
# Name: (ripple, 0.87), dtype: float64
# data_date
# 2018-04-29    0.871
# Name: (ripple, 0.871), dtype: float64
# data_date
# 2018-04-22    0.8757
# Name: (ripple, 0.8757), dtype: float64
# data_date
# 2018-03-07    0.8804
# Name: (ripple, 0.8804), dtype: float64
# data_date
# 2018-05-06    0.8819
# Name: (ripple, 0.8819), dtype: float64
# data_date
# 2018-02-04    0.8892
# Name: (ripple, 0.8892), dtype: float64
# data_date
# 2018-05-04    0.8923
# Name: (ripple, 0.8923), dtype: float64
# data_date
# 2018-02-25    0.901
# 2018-03-02    0.901
# Name: (ripple, 0.901), dtype: float64
# data_date
# 2018-03-03    0.902
# Name: (ripple, 0.902), dtype: float64
# data_date
# 2018-03-01    0.9065
# Name: (ripple, 0.9065), dtype: float64
# data_date
# 2018-05-05    0.9091
# Name: (ripple, 0.9091), dtype: float64
# data_date
# 2018-02-26    0.9112
# Name: (ripple, 0.9112), dtype: float64
# data_date
# 2018-02-03    0.9139
# Name: (ripple, 0.9139), dtype: float64
# data_date
# 2018-02-28    0.9141
# Name: (ripple, 0.9141), dtype: float64
# data_date
# 2018-02-24    0.9158
# Name: (ripple, 0.9158), dtype: float64
# data_date
# 2018-03-04    0.9166
# Name: (ripple, 0.9166), dtype: float64
# data_date
# 2018-02-23    0.9266
# Name: (ripple, 0.9266), dtype: float64
# data_date
# 2018-02-22    0.9299
# Name: (ripple, 0.9299), dtype: float64
# data_date
# 2018-03-06    0.9331
# Name: (ripple, 0.9331), dtype: float64
# data_date
# 2018-02-27    0.9358
# Name: (ripple, 0.9358), dtype: float64
# data_date
# 2018-04-24    0.9365
# Name: (ripple, 0.9365), dtype: float64
# data_date
# 2017-12-24    0.9448
# Name: (ripple, 0.9448), dtype: float64
# data_date
# 2017-12-21    0.9512
# Name: (ripple, 0.9512), dtype: float64
# data_date
# 2018-02-11    0.9661
# Name: (ripple, 0.9661), dtype: float64
# data_date
# 2017-12-25    0.9808
# Name: (ripple, 0.9808), dtype: float64
# data_date
# 2018-02-21    0.9909
# Name: (ripple, 0.9909), dtype: float64
# data_date
# 2017-12-26    1.0011
# Name: (ripple, 1.0011), dtype: float64
# data_date
# 2017-12-22    1.002
# Name: (ripple, 1.002), dtype: float64
# data_date
# 2018-02-13    1.0021
# Name: (ripple, 1.0021), dtype: float64
# data_date
# 2018-03-05    1.0143
# Name: (ripple, 1.0143), dtype: float64
# data_date
# 2018-02-10    1.0302
# Name: (ripple, 1.0302), dtype: float64
# data_date
# 2018-02-12    1.032
# Name: (ripple, 1.032), dtype: float64
# data_date
# 2018-02-01    1.0332
# Name: (ripple, 1.0332), dtype: float64
# data_date
# 2017-12-23    1.0394
# Name: (ripple, 1.0394), dtype: float64
# data_date
# 2018-02-14    1.0461
# Name: (ripple, 1.0461), dtype: float64
# data_date
# 2018-02-20    1.0921
# Name: (ripple, 1.0921), dtype: float64
# data_date
# 2018-02-16    1.0982
# Name: (ripple, 1.0982), dtype: float64
# data_date
# 2018-01-17    1.0998
# Name: (ripple, 1.0998), dtype: float64
# data_date
# 2018-01-31    1.1021
# Name: (ripple, 1.1021), dtype: float64
# data_date
# 2018-02-19    1.1069
# Name: (ripple, 1.1069), dtype: float64
# data_date
# 2018-02-18    1.1084
# Name: (ripple, 1.1084), dtype: float64
# data_date
# 2018-02-15    1.1117
# Name: (ripple, 1.1117), dtype: float64
# data_date
# 2018-02-17    1.1441
# Name: (ripple, 1.1441), dtype: float64
# data_date
# 2017-12-27    1.1472
# Name: (ripple, 1.1472), dtype: float64
# data_date
# 2018-01-30    1.1918
# Name: (ripple, 1.1918), dtype: float64
# data_date
# 2017-12-28    1.2092
# Name: (ripple, 1.2092), dtype: float64
# data_date
# 2018-01-27    1.2125
# Name: (ripple, 1.2125), dtype: float64
# data_date
# 2018-01-26    1.2299
# Name: (ripple, 1.2299), dtype: float64
# data_date
# 2018-01-28    1.2609
# Name: (ripple, 1.2609), dtype: float64
# data_date
# 2018-01-29    1.2895
# Name: (ripple, 1.2895), dtype: float64
# data_date
# 2018-01-22    1.2994
# Name: (ripple, 1.2994), dtype: float64
# data_date
# 2018-01-23    1.3097
# Name: (ripple, 1.3097), dtype: float64
# data_date
# 2018-01-25    1.33
# Name: (ripple, 1.33), dtype: float64
# data_date
# 2018-01-24    1.3472
# Name: (ripple, 1.3472), dtype: float64
# data_date
# 2018-01-16    1.3804
# Name: (ripple, 1.3804), dtype: float64
# data_date
# 2018-01-21    1.4215
# Name: (ripple, 1.4215), dtype: float64
# data_date
# 2018-01-18    1.4964
# Name: (ripple, 1.4964), dtype: float64
# data_date
# 2018-01-20    1.555
# Name: (ripple, 1.555), dtype: float64
# data_date
# 2017-12-29    1.5794
# Name: (ripple, 1.5794), dtype: float64
# data_date
# 2018-01-19    1.5836
# Name: (ripple, 1.5836), dtype: float64
# data_date
# 2018-01-15    1.8065
# Name: (ripple, 1.8065), dtype: float64
# data_date
# 2018-01-14    1.8654
# Name: (ripple, 1.8654), dtype: float64
# data_date
# 2018-01-11    1.8688
# Name: (ripple, 1.8688), dtype: float64
# data_date
# 2017-12-31    1.9115
# Name: (ripple, 1.9115), dtype: float64
# data_date
# 2018-01-01    1.9216
# Name: (ripple, 1.9216), dtype: float64
# data_date
# 2018-01-10    1.9217
# Name: (ripple, 1.9217), dtype: float64
# data_date
# 2018-01-12    2.0067
# Name: (ripple, 2.0067), dtype: float64
# data_date
# 2018-01-13    2.0268
# Name: (ripple, 2.0268), dtype: float64
# data_date
# 2018-01-02    2.0549
# Name: (ripple, 2.0549), dtype: float64
# data_date
# 2017-12-30    2.0963
# Name: (ripple, 2.0963), dtype: float64
# data_date
# 2018-01-09    2.288
# Name: (ripple, 2.288), dtype: float64
# data_date
# 2018-01-03    2.4819
# Name: (ripple, 2.4819), dtype: float64
# data_date
# 2018-01-08    2.5078
# Name: (ripple, 2.5078), dtype: float64
# data_date
# 2018-01-05    2.6657
# Name: (ripple, 2.6657), dtype: float64
# data_date
# 2018-01-06    2.667
# Name: (ripple, 2.667), dtype: float64
# data_date
# 2018-01-07    2.7094
# Name: (ripple, 2.7094), dtype: float64
# data_date
# 2018-01-04    2.9995
# Name: (ripple, 2.9995), dtype: float64
